# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Notebook-setup" data-toc-modified-id="Notebook-setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Notebook setup</a></span><ul class="toc-item"><li><span><a href="#define-user-inputted-values" data-toc-modified-id="define-user-inputted-values-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>define user-inputted values</a></span></li><li><span><a href="#prepare-notebook-wide-references" data-toc-modified-id="prepare-notebook-wide-references-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>prepare notebook-wide references</a></span></li><li><span><a href="#Define-functions" data-toc-modified-id="Define-functions-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Define functions</a></span></li></ul></li><li><span><a href="#Extract-company-list-data" data-toc-modified-id="Extract-company-list-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Extract company list data</a></span><ul class="toc-item"><li><span><a href="#Afrilabs---map-of-African-accelerators-/-hubs" data-toc-modified-id="Afrilabs---map-of-African-accelerators-/-hubs-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Afrilabs - map of African accelerators / hubs</a></span></li><li><span><a href="#Google-Places-API" data-toc-modified-id="Google-Places-API-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Google Places API</a></span><ul class="toc-item"><li><span><a href="#Nearby-places" data-toc-modified-id="Nearby-places-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Nearby places</a></span><ul class="toc-item"><li><span><a href="#analyze-data" data-toc-modified-id="analyze-data-2.2.1.1"><span class="toc-item-num">2.2.1.1&nbsp;&nbsp;</span>analyze data</a></span></li></ul></li><li><span><a href="#Text-search" data-toc-modified-id="Text-search-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Text search</a></span></li></ul></li><li><span><a href="#corporate-accelerators.net" data-toc-modified-id="corporate-accelerators.net-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>corporate-accelerators.net</a></span></li><li><span><a href="#GALI" data-toc-modified-id="GALI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>GALI</a></span></li><li><span><a href="#Companiesss.com" data-toc-modified-id="Companiesss.com-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Companiesss.com</a></span></li><li><span><a href="#Yellow-Pages-of-Africa" data-toc-modified-id="Yellow-Pages-of-Africa-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Yellow Pages of Africa</a></span></li></ul></li><li><span><a href="#Extract-company-list-data---Asia" data-toc-modified-id="Extract-company-list-data---Asia-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Extract company list data - Asia</a></span><ul class="toc-item"><li><span><a href="#Companiess.com" data-toc-modified-id="Companiess.com-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Companiess.com</a></span></li><li><span><a href="#Endeavor-Indonesia" data-toc-modified-id="Endeavor-Indonesia-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Endeavor Indonesia</a></span></li><li><span><a href="#GBG-indonesia" data-toc-modified-id="GBG-indonesia-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>GBG indonesia</a></span></li><li><span><a href="#1000-Startup-Digital" data-toc-modified-id="1000-Startup-Digital-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>1000 Startup Digital</a></span></li><li><span><a href="#Compass-List" data-toc-modified-id="Compass-List-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Compass List</a></span><ul class="toc-item"><li><span><a href="#OLD-code" data-toc-modified-id="OLD-code-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>OLD code</a></span></li><li><span><a href="#Startups" data-toc-modified-id="Startups-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Startups</a></span></li><li><span><a href="#Investors" data-toc-modified-id="Investors-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Investors</a></span></li><li><span><a href="#Merge-directory" data-toc-modified-id="Merge-directory-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>Merge directory</a></span></li><li><span><a href="#Scrape-Indonesian-startup-pages" data-toc-modified-id="Scrape-Indonesian-startup-pages-3.5.5"><span class="toc-item-num">3.5.5&nbsp;&nbsp;</span>Scrape Indonesian startup pages</a></span></li></ul></li><li><span><a href="#Startup-Ranking" data-toc-modified-id="Startup-Ranking-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Startup Ranking</a></span></li><li><span><a href="#Startup-ideas" data-toc-modified-id="Startup-ideas-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Startup-ideas</a></span></li><li><span><a href="#Private-Banking" data-toc-modified-id="Private-Banking-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Private Banking</a></span></li><li><span><a href="#Scholaro" data-toc-modified-id="Scholaro-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Scholaro</a></span></li></ul></li><li><span><a href="#Indonesia-specific-Associations" data-toc-modified-id="Indonesia-specific-Associations-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Indonesia-specific Associations</a></span><ul class="toc-item"><li><span><a href="#ASPILUKI" data-toc-modified-id="ASPILUKI-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>ASPILUKI</a></span></li><li><span><a href="#APMI" data-toc-modified-id="APMI-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>APMI</a></span></li><li><span><a href="#ABDI" data-toc-modified-id="ABDI-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>ABDI</a></span></li><li><span><a href="#APKOMINDO" data-toc-modified-id="APKOMINDO-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>APKOMINDO</a></span></li><li><span><a href="#FinTech-ID" data-toc-modified-id="FinTech-ID-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>FinTech ID</a></span></li><li><span><a href="#IDEA" data-toc-modified-id="IDEA-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>IDEA</a></span></li><li><span><a href="#APJII" data-toc-modified-id="APJII-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>APJII</a></span></li></ul></li><li><span><a href="#Indonesia-specific-articles" data-toc-modified-id="Indonesia-specific-articles-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Indonesia-specific articles</a></span><ul class="toc-item"><li><span><a href="#inc42" data-toc-modified-id="inc42-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>inc42</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Notebook setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import glob
import os

import datetime
import time
import ast

import itertools
import pickle

import requests
import re
import json
import bs4
import googlemaps

import cfscrape
import html

# %% [markdown]
# ## define user-inputted values

# %%
# define key countries
country_list = ['Indonesia', 'Senegal',  'Vietnam', 'Kenya', 'Nigeria']

# %%
# define folder names
output_folder = 'outputs'
raw_outputs_folder = 'z raw'

# %%
# update gmaps key if needed
gmaps_key = 'AIzaSyCHVHlO891J3s5UaCGfH8gkixvUB1e8pWs'

# input keywords for text search
keywords = ["accelerator", "hub", "startup", "accélérateur", "incubateur", "incubator", "company", "business"]

# %% [markdown]
# ## prepare notebook-wide references

# %%
# date today to mark date scraped
date_today = datetime.date.today().isoformat()

# %%
# get country metadata from WBG
df_countries_all = pd.read_csv('data/wbg_country_metadata.csv')
df_countries = df_countries_all[df_countries_all['name'].isin(country_list)]

# %%
# create raw folder
if not os.path.exists(os.path.join(output_folder)):
    os.mkdir(os.path.join(output_folder))
if not os.path.exists(os.path.join(output_folder, raw_outputs_folder)):
    os.mkdir(os.path.join(output_folder, raw_outputs_folder))

# create folders for each country
for cou in country_list:
    if not os.path.exists(os.path.join(output_folder, cou)):
        os.mkdir(os.path.join(output_folder, cou))

# %%
# initialize data counter
df_data_counter = pd.DataFrame(columns=['data_source', 'number_of_extracted_cols'] + country_list)

# %% [markdown]
# ## Define functions

# %%
def cfDecodeEmail(encodedString):
    r = int(encodedString[:2],16)
    email = ''.join([chr(int(encodedString[i:i+2], 16) ^ r) for i in range(2, len(encodedString), 2)])
    return(email)

# %%
def extract_cou_metadata(df_countries, cou):
    df_temp = df_countries[df_countries['name'] == cou]
    cou_iso2 = df_temp['iso2'].values[0]
    cou_iso3 = df_temp['iso3'].values[0]
    cou_capitalCity = df_temp['capitalCity'].values[0]

    cou_lat = ast.literal_eval(df_temp['geo'].values[0])['lat']
    cou_lng = ast.literal_eval(df_temp['geo'].values[0])['lng']
    cou_geo = (cou_lat, cou_lng)
    
    return((cou, cou_iso2, cou_iso3, cou_capitalCity, cou_geo))

# %%
def update_data_counter(data_source, country_list, df, df_data_counter, geo_col, exact_match=False):
    
    cou_count = {}
    cou_count['data_source'] = data_source
    cou_count['number_of_extracted_cols'] = df.shape[1]
    
    for cou in country_list:
        if exact_match:
            df_temp = df[(df[geo_col] == cou).fillna(False)]
        else:
            df_temp = df[df[geo_col].str.contains(cou).fillna(False)]
        cou_count[cou] = df_temp.shape[0]
        if df_temp.shape[0] > 0:
            df_temp.to_csv(os.path.join(output_folder, cou,"%s - %s - %s.csv" % (date_today, data_source, cou)), index=False)

    # update counter
    df_data_counter = df_data_counter.append(pd.DataFrame.from_dict(cou_count, orient='index').T, ignore_index=True)
    
    return(df_data_counter)

# %%
def get_dummy_type_cols(df_gmaps_all, col="types"):
    for genre in set.union(*df_gmaps_all[col].apply(set)):
        df_gmaps_all[genre] = df_gmaps_all.apply(lambda _: int(_[col].count(genre)), axis=1)
    
    return(df_gmaps_all)

# %%
def extract_GPlaces_nearby_places(cou, cou_geo, data_source, gmaps_key):
    # input Places API key
    gmaps = googlemaps.Client(key=gmaps_key)

    # get first N batches of 20 results
    batch_num = 50

    # use kenya capital (Abuja) geocoordinates. Approximate radius with 480km
    results = gmaps.places_nearby(radius=520000, location=cou_geo)
    df_gmaps_all = pd.DataFrame(results['results'])

    for batch in range(batch_num):
        # get next 20 results
        try:
            page_token_next = results['next_page_token']
        except:
            break

        # wait for 2 seconds before getting new data
        time.sleep(2)
        results = gmaps.places_nearby(page_token=page_token_next)

        df_gmaps_all = df_gmaps_all.append(pd.DataFrame(results['results']))

        print("batch %s done" % str(batch + 1))

    df_gmaps_all.reset_index(drop=True, inplace=True)
    df_gmaps_all['country'] = cou
    print(df_gmaps_all.shape)

    for genre in set.union(*df_gmaps_all['types'].apply(set)):
        df_gmaps_all[genre] = df_gmaps_all.apply(lambda _: int(_['types'].count(genre)), axis=1)
    
    df_gmaps_all.to_csv(os.path.join(output_folder, cou,"%s - %s - %s.csv" % (date_today, data_source, cou)), index=False)
    
    return(df_gmaps_all)

# %%
def extract_GPlaces_textsearch(cou, cou_iso2, keywords, data_source, gmaps_key):
    df_gmaps_textsearch = pd.DataFrame()
    
    gmaps = googlemaps.Client(key=gmaps_key)
    print(cou)
    for keyword in keywords:

        results_textsearch = gmaps.places(keyword, region=cou_iso2)
        df_temp = pd.DataFrame(results_textsearch['results'])

        df_temp['keyword_for_text_search'] = keyword
        df_temp['country'] = cou
        print(keyword, df_temp.shape)
        df_gmaps_textsearch = df_gmaps_textsearch.append(df_temp)

    if df_gmaps_textsearch.shape[0] > 0:
        df_gmaps_textsearch = df_gmaps_textsearch.reset_index(drop=True)
        df_gmaps_textsearch = get_dummy_type_cols(df_gmaps_textsearch)
        print(df_gmaps_textsearch.shape)
    
        df_gmaps_textsearch.to_csv(os.path.join(output_folder, cou,"%s - %s - %s.csv" % (date_today, data_source, cou)), index=False)
        
    return(df_gmaps_textsearch)

# %%
def extract_gali(url):
    
    r = requests.get(url)
    page_source = r.content
    soup = bs4.BeautifulSoup(page_source, "lxml")
    
    df_gali = pd.DataFrame()

    for dir_result in soup.find_all('li', attrs={"class":"directory-result"}):
        dict_gali = {}
        dict_gali['name'] = dir_result.find_all('span', {'class': 'org-name'})[0].getText()

        try:
            dict_gali['url'] = dir_result.find_all('a', {'class': 'org-name'})[0]['href']
        except:
            dict_gali['url'] = np.nan

        try:
            dict_gali['location'] = dir_result.find_all('span', {'class': 'location'})[0].getText()
        except:
            dict_gali['location'] = np.nan

        try:
            dict_gali['description'] = dir_result.find_all('p', {'class': 'introtext'})[0].getText()

        except:
            dict_gali['description'] = np.nan 
        region_list = []
        for tag in dir_result.find_all('li', {'class': 'tag'}):
            region_list.append(tag.getText())

        dict_gali['region_list'] = '|'.join(region_list)

        df_gali = df_gali.append(pd.DataFrame.from_dict(dict_gali, orient='index').T, ignore_index=True)
    
    return(df_gali)

# %%
def extract_ypa(soup, dict_ypa, subtopic):
    for dir_entry in soup.find_all("div", {'class': 'ct-main-text'}):
        name = dir_entry.find("div", {"class": "ct-product--tilte"}).getText().strip()
        try:
            location = dir_entry.find("i", {"class": "fa fa-map-marker"}).next_element.strip()
        except:
            location = np.nan

        try:
            company_url = dir_entry.find("a")['href']
        except:
            company_url = np.nan
        dict_ypa[name] = [location, company_url, subtopic]
    return(dict_ypa)

# %%
def extract_ypa_country(country, date_today):
    data_source = 'Yellow Pages of Africa (companies)'
    base_url = 'http://www.yellowpagesofafrica.com'
    append_url_cou = '/country/%s/' % str.lower(country)

    # get categories
    r = requests.get(base_url + append_url_cou)
    page_source = r.content
    soup = bs4.BeautifulSoup(page_source, "lxml")

    ## extract all topics
    soup_main = soup.find("div", {"class":"col-sm-12 col-lg-12 ct-u-marginBottom40"})
    ypa_topics = soup_main.find_all("div", {"class":"row"})

    topics_list = []
    for ix, topic in enumerate(ypa_topics):
        if topic.find("ins", {"class": "adsbygoogle"}):
            continue
        if topic.find("h2"):
            main_cat = topic.find("h2").getText()
        else:
            for sub_cat in topic.find_all('a'):
                sub_cat_name = sub_cat.getText().strip()
                sub_cat_url = base_url + sub_cat['href']
                topics_list.append([main_cat, sub_cat_name, sub_cat_url])

    df_ypa_topics = pd.DataFrame(topics_list, columns=['industry_level_1', 'industry_level_2', 'industry_url'])
    df_ypa_topics['industry_level_2'].is_unique

    # extract company metadata
    dict_ypa = {}

    for subtopic in df_ypa_topics['industry_level_2']:
        url = df_ypa_topics[df_ypa_topics['industry_level_2'] == subtopic]['industry_url'].values[0]
        # get categories
        r = requests.get(url)
        page_source = r.content
        soup = bs4.BeautifulSoup(page_source, "lxml")
        dict_ypa = extract_ypa(soup, dict_ypa, subtopic)

        # get rest of the pages (if any)
        if soup.find("ul", {"class": "pagination"}):
            link_list = []
            for link in soup.find("ul", {"class": "pagination"}).find_all("a"):
                if link['href'] != '#':
                    link_list.append(link['href'])

            for link in list(set(link_list)):
                url = base_url + link

                # get categories
                r = requests.get(url)
                page_source = r.content
                soup = bs4.BeautifulSoup(page_source, "lxml")
                dict_ypa = extract_ypa(soup, dict_ypa, subtopic)

    # export CSV            
    df_ypa_cou = pd.DataFrame(dict_ypa).T.reset_index()
    df_ypa_cou.columns = ['name', 'location', 'url', 'industry_level_2']
    df_ypa_cou_topic = df_ypa_cou.merge(df_ypa_topics, how='left', on='industry_level_2')
    df_ypa_cou_topic['country'] = country
    df_ypa_cou_topic.to_csv(os.path.join(output_folder, cou,"%s - %s - %s.csv" % (date_today, data_source, country)), index=False)
    
    return(df_ypa_cou_topic)

# %%
def extract_startupranking_directory(entity_list, startupranking_entity_dict):
    for entity_entry in entity_list:
        # entity_entry = entity_list[0]
        entity_name = entity_entry.find('div', {"class":"name"}).getText()

        # get company metadata
        startupranking_entity_dict[entity_name] = {}
        startupranking_entity_dict[entity_name]['entity_logo'] = entity_entry.find('img')['src']
        startupranking_entity_dict[entity_name]['entity_dir_url'] = base_url + entity_entry.find('div', {"class":"name"}).find('a')['href']
        startupranking_entity_dict[entity_name]['entity_desc'] = entity_entry.find('td', {"class":"description"}).getText().strip().replace("  ","")
        startupranking_entity_dict[entity_name]['entity_type'] = entity_type

        # get company statistics
        startupranking_entity_dict[entity_name]['entity_startupranking_sr_score'] = int(entity_entry.find('td', {"class":"sr-score"}).getText().strip().replace(",",""))
        startupranking_entity_dict[entity_name]['entity_startupranking_world_rank'] = int(entity_entry.find('td').getText().strip().replace(",",""))
        startupranking_entity_dict[entity_name]['entity_startupranking_country_rank'] =int(entity_entry.find('div', {"class":"country-rank"}).getText().strip().replace(",",""))
        
    return(startupranking_entity_dict)

# %%
def extract_startupranking_company_data(scraper, entity_dict, investors_dict, founders_dict):

    # for entity_name in list(entity_dict.keys()):
    for entity_name in list(entity_dict.keys()):
#         print('scraping %s' % entity_name)

        entity_dir_url = entity_dict[entity_name]['entity_dir_url']
        r = scraper.get(entity_dir_url)
        soup = bs4.BeautifulSoup(r.content, "lxml")

        try:
            entity_dict[entity_name]['entity_country'] = soup.find("div", {"class":"country-rank"}).getText()

            # compile company stats
            entity_dict[entity_name]['entity_startupranking_sr_web'] = int(soup.find('h4', string='SR Web').parent.find('p').getText().strip().replace(",",""))
            entity_dict[entity_name]['entity_startupranking_sr_social'] = int(soup.find('h4', string='SR Social').parent.find('p').getText().strip().replace(",",""))

            try:
                entity_dict[entity_name]['entity_desc_tagline'] = soup.find("div", {"class": "su-phrase"}).getText().strip()
            except:
                pass
            try:
                entity_dict[entity_name]['entity_desc_details'] = soup.find('div', {"class": "su-info"}).find('p').getText().strip()
            except:
                pass

            try:
                entity_dict[entity_name]['entity_founding_date_text'] = soup.find('div', {"class": "su-info"}).find('p', {"class": "su-loc"}).getText().strip()
                entity_dict[entity_name]['entity_founding_date_datetime'] = pd.to_datetime(soup.find('div', {"class": "su-info"}).find('p', {"class": "su-loc"}).getText().strip().replace('Founded: ',''))
            except:
                pass

            try:
                social_media_list = soup.find('div', {"class": "su-info"}).find('ul', {'class': 'su-social'}).find_all('li')
                for social_media_entry in social_media_list:
                    entity_dict[entity_name]['entity_socmed_'+str.lower(social_media_entry.find('a')['class'][0])] = social_media_entry.find('a')['href']
            except:
                pass

            try:
                entity_dict[entity_name]['entity_industry_list'] = [tag.getText().strip() for tag in soup.find("div", {"class": "su-tags"}).find_all('li')]
            except:
                pass


            # get social media statistics
            for stats in soup.find_all('div', {"class": "col-03"}):
                try:
                    attribute_type = str.lower(stats.find('h3').getText().strip())

                    for stat in stats.find_all('li'):
                        attribute_name = str.lower(stat.find('span').previousSibling.strip())
                        attribute_value = float(stat.find('span').getText().strip().replace(',',''))
                        entity_dict[entity_name]['entity_socmed_'+ attribute_type+ '_'+attribute_name] = attribute_value
                except:
                    pass

            # get funding data
            entity_dict[entity_name]['entity_funding_list'] = []
            investment_table = soup.find('h2', string=entity_name+' Funding').parent.find('table')
            row_headers = [th.getText() for th in investment_table.find('thead').find_all('th')]

            # fill in funding details per startup
            if investment_table.find('tbody').getText().strip() == 'There are no funding rounds.':
                entity_dict[entity_name]['entity_funding_list'] = []
            else:
                for row in investment_table.find('tbody').find_all('tr'):
                    row_list = [val.getText().strip() for val in row.find_all('td')]
                    row_dict = {}
                    for header, val in zip(row_headers, row_list):
                        row_dict[header] = val
                    entity_dict[entity_name]['entity_funding_list'].append(row_dict)

                    # fill in investors dict
                    if row.find('ul'):
                        for investor in row.find('ul').find_all('li'):
                            investor_name = investor.getText().strip()
                            if investor_name != '':
                                # create new entry if does not exist
                                if investor_name not in investors_dict.keys():
                                    investors_dict[investor_name] = {}
                                    investors_dict[investor_name]['entity_dir_url'] = base_url + investor.find('a')['href']
                                    investors_dict[investor_name]['entity_funding_list'] = []
                                    investors_dict[investor_name]['entity_type'] = 'investor'

                                # create dictionary for new row
                                row_dict = {}
                                row_dict['entity_company_funded'] = entity_name
                                row_dict['entity_company_funded_country'] = country
                                for header, val in zip(row_headers[:3], row.find_all('td')[:3]):
                                    row_dict['entity_' + str.lower(header) + '_funded'] = val.getText().strip()

                                investors_dict[investor_name]['entity_funding_list'].append(row_dict)
        #                         row_dict = {}
        #                         row_dict = {
        #                             'entity_name': investor_name,
        #                             'entity_dir_url': base_url + investor.find('a')['href'],
        #                             'entity_company_funded': entity_name,
        #                             'entity_type': 'investor',
        #                             'entity_company_funded_country': country
        #                         }
        #                         for header, val in zip(row_headers[:3], row.find_all('td')[:3]):
        #                             row_dict['entity_' + str.lower(header) + '_funded'] = val.getText().strip()

        #                         investors_dict.append(row_dict)                    

            # get founder/team data
            entity_dict[entity_name]['entity_founders_list'] = []
            team_table = soup.find('h2', string=entity_name+' Team').parent.find('table')
            row_headers_team = [th.getText() for th in team_table.find('thead').find_all('th')]

            if team_table.find('tbody').getText().strip() == 'There are no team members.':
                entity_dict[entity_name]['entity_founders_list'] = []
            else:
                for row in team_table.find('tbody').find_all('tr'):
                    row_list = [val.getText().strip() for val in row.find_all('td')]
                    row_dict = {}
                    for header, val in zip(row_headers_team, row_list):
                        row_dict[header] = val
                    entity_dict[entity_name]['entity_founders_list'].append(row_dict)

                    # fill in founders dict
                    founder_name = row.find('td', {'class':'tleft'}).getText().strip()
                    if founder_name != '':
                        # create new entry if does not exist
                        if founder_name not in founders_dict.keys():
                            founders_dict[founder_name] = {}
                            founders_dict[founder_name]['entity_dir_url'] = base_url + row.find('a')['href']
                            founders_dict[founder_name]['entity_founding_list'] = []
                            founders_dict[founder_name]['entity_photo'] = row.find('img')['src']
                            founders_dict[founder_name]['entity_type'] = 'founder'

                        # create dictionary for new row
                        row_dict = {}
                        row_dict['entity_company_founded'] = entity_name
                        row_dict['entity_company_founded_country'] = country
                        for header, val in zip(row_headers_team[:3], row.find_all('td')[:3]):
                            row_dict['entity_' + str.lower(header)] = val.getText().strip()

                        founders_dict[founder_name]['entity_founding_list'].append(row_dict)

        #             row_dict = {}
        #             row_dict = {
        #                 'entity_name': founder_name,
        #                 'entity_dir_url': base_url + row.find('a')['href'],
        #                 'entity_photo': row.find('img')['src'],
        #                 'entity_type': 'founder',
        #                 'entity_company_founded_country': country
        #             }

        #             for header, val in zip(row_headers_team[1:], row.find_all('td')[1:]):
        #                 founders_dict[founder_name]['entity_' + str.lower(header) + '_in_team'] = val.getText().strip()
        except:
            pass
    return(entity_dict, investors_dict, founders_dict)

# %%
def extract_startupranking_founder_data(scraper, founders_dict):
    for entity_name in list(founders_dict.keys()):
        print('scraping %s' % entity_name)

        entity_dir_url = founders_dict[entity_name]['entity_dir_url']    
        r = scraper.get(entity_dir_url)
        soup = bs4.BeautifulSoup(r.content, "lxml")

        try:
            attribute_list = [val.strip() for val in soup.find('div', {"class": "su-info"}).find('p', {'class': 'su-loc'}).getText().replace('\n','').split('   ') if val != '']
            for entry in attribute_list:
                entry_list = entry.split(': ')
                if str.lower(entry_list[0]) == 'born':
                    founders_dict[entity_name]['entity_birth_date_text'] = entry_list[1]
                    founders_dict[entity_name]['entity_birth_date_datetime'] = pd.to_datetime(entry_list[1])
                else:
                    founders_dict[entity_name]['entity_'+str.lower(entry_list[0])] = entry_list[1]
        except:
            pass

        try:
            social_media_list = soup.find('div', {"class": "su-info"}).find('ul', {'class': 'su-social'}).find_all('li')
            for social_media_entry in social_media_list:
                founders_dict[entity_name]['entity_socmed_'+str.lower(social_media_entry.find('a')['class'][0])] = social_media_entry.find('a')['href']
        except:
            pass
        
    return(founders_dict)

# %%
def convert_startupranking_to_df(founders_dict, nested_col, data_source, unique_cou_col,
                                 df_data_counter=df_data_counter, country_list=country_list,
                                 date_today=date_today, output_folder=output_folder,
                                 raw_outputs_folder=raw_outputs_folder):
    # convert dict to list
#     df_list = []
#     for key, item in founders_dict.items():
#         item['entity_name'] = key

#         df_list.append(item)

#     with open('%s - %s.pkl' % (date_today, data_source), 'wb') as outfile:
#         pickle.dump(df_list, outfile)

#     cols = list(df_list[0].keys())
#     cols.remove(nested_col)

#     try:
#         df = pd.io.json.json_normalize(df_list, nested_col, cols, errors='ignore')
#     except:
#         df = pd.io.json.json_normalize(df_list)
    
    df = pd.DataFrame.from_dict(founders_dict, orient='index')
    print(data_source, df.shape)
    print(df[unique_cou_col].value_counts())

    # export
    df.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

    # update data counter
    df_data_counter = update_data_counter(data_source, country_list, df, df_data_counter, unique_cou_col, exact_match=True)
    
    return(df, df_data_counter)

# %% [markdown]
# # Extract company list data

# %% [markdown]
# ## Afrilabs - map of African accelerators / hubs
# http://www.afrilabs.com/afrilabs-passport/

# %%
# pull page source of Afrilabs page
data_source = 'Afrilabs (accelerators and hubs)'
url = 'http://www.afrilabs.com/afrilabs-passport/'

r = requests.get(url)
page_source = r.content
soup = bs4.BeautifulSoup(page_source, "lxml")

# extract maps script
script = soup.find('script', text=re.compile('\.maps'))

# extract the maps data
json_text = re.search(r'.*\.maps\((.*)\)\.data\("wpgmp_maps"\);}\);$', script.string).group(1)
data = json.loads(json_text)
df_afrilabs = pd.DataFrame(data['places'])

# extract nested data on location
df_afrilabs_location = pd.DataFrame()
for ix in df_afrilabs.index:
    df_temp = pd.DataFrame.from_dict(df_afrilabs['location'].ix[ix], orient='index')
    df_temp.columns = [ix]
    df_temp = df_temp.T
    df_afrilabs_location = df_afrilabs_location.append(df_temp)
    
# merge scraped data
df_afrilabs_full = df_afrilabs.join(df_afrilabs_location)[list(df_afrilabs.columns) + list(df_afrilabs_location.columns)]
df_afrilabs_full.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)))

# process data
# drop non-unique cols
unique_cols = df_afrilabs_full.apply(lambda x: len(x.astype(str).unique()), axis=0)
unique_cols_list = list(unique_cols[unique_cols > 2].index)

df_afrilabs_full = df_afrilabs_full[unique_cols_list]

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_afrilabs_full, df_data_counter, 'country', exact_match=True)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %% [markdown]
# ## Google Places API
# Documentation here: https://developers.google.com/places/web-service/search
# ### Nearby places

# %%
data_source = 'Google Places API, Nearby Places search (establishments)'

df_gplaces = pd.DataFrame()
for country in country_list:
    cou, cou_iso2, cou_iso3, cou_capitalCity, cou_geo = extract_cou_metadata(df_countries, country)
    print(cou, cou_geo)
    df_temp = extract_GPlaces_nearby_places(cou, cou_geo, data_source, gmaps_key)
    
    df_gplaces = df_gplaces.append(df_temp)
    
df_gplaces.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_gplaces, df_data_counter, 'country', exact_match=True)
# Out:
# Senegal (14.7247, -17.4734)
# batch 1 done
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# batch 2 done
# (60, 14)
# Indonesia (-6.19752, 106.83)
# (2, 11)
# Vietnam (21.0069, 105.825)
# (2, 11)
# Kenya (-1.27975, 36.8126)
# batch 1 done
# batch 2 done
# (60, 14)
# Nigeria (9.05804, 7.48906)
# batch 1 done
# batch 2 done
# (60, 14)

# %% [markdown]
# #### analyze data

# %%
establishment_list = list(set.union(*df_gplaces['types'].apply(set)))
df_gplaces[establishment_list].sum().sort_values().plot(kind='barh', figsize=(5,8))
plt.title("Establishment types, scraped from %s" % data_source)
# Out:
# Text(0.5,1,'Establishment types, scraped from Google Places API, Nearby Places search (establishments)')

# %%
df_gplaces.groupby('country')[list(df_gplaces[establishment_list].sum().sort_values().tail(10).index)].sum().plot(kind='barh', stacked=True)
plt.legend(bbox_to_anchor=(1,1))
plt.title("Establishment types by country, scraped from %s" % data_source)
# Out:
# Text(0.5,1,'Establishment types by country, scraped from Google Places API, Nearby Places search (establishments)')

# %% [markdown]
# ### Text search

# %%
data_source = 'Google Places API, Text search (accelerators, hubs, startups, companies)'

df_gplaces_text = pd.DataFrame()
for country in country_list:
    cou, cou_iso2, cou_iso3, cou_capitalCity, cou_geo = extract_cou_metadata(df_countries, country)
    print(cou, cou_iso2)
    df_temp = extract_GPlaces_textsearch(cou, cou_iso2, keywords, data_source, gmaps_key)
    
    df_gplaces_text = df_gplaces_text.append(df_temp)
    print("=======================")
    
df_gplaces_text.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_gplaces_text, df_data_counter, 'country', exact_match=True)
# Out:
# Senegal SN
# Senegal
# accelerator (0, 2)
# hub (0, 2)
# startup (0, 2)
# accélérateur (0, 2)
# incubateur (0, 2)
# incubator (0, 2)
# company (17, 14)
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# business (4, 14)
# (21, 23)
# ...
# Indonesia ID
# Indonesia
# accelerator (2, 14)
# hub (1, 13)
# startup (0, 2)
# accélérateur (0, 2)
# incubateur (0, 2)
# incubator (1, 14)
# company (20, 14)
# business (2, 12)
# (26, 22)
# ...
# Vietnam VN
# Vietnam
# accelerator (0, 2)
# hub (1, 14)
# startup (0, 2)
# accélérateur (0, 2)
# incubateur (0, 2)
# incubator (0, 2)
# company (20, 14)
# business (1, 12)
# (22, 23)
# ...
# Kenya KE
# Kenya
# accelerator (1, 13)
# hub (6, 14)
# startup (0, 2)
# ...

# %% [markdown]
# ## corporate-accelerators.net

# %%
r = requests.get('https://raw.githubusercontent.com/florianheinemann/www-corporate-accelerators-net/master/_data/Accelerators.json')
data_source = 'Corporate Accelerators (accelerators)'
df_corp_accelerators = pd.DataFrame(r.json())

# export all
df_corp_accelerators.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_corp_accelerators, df_data_counter, 'Accelerator locations', exact_match=False)

# %% [markdown]
# ## GALI
# https://www.galidata.org/accelerators/directory/

# %%
# identify last page
data_source = 'GALI (accelerators)'
root_url = 'https://www.galidata.org/accelerators/directory/'

r = requests.get(root_url)
page_source = r.content
soup = bs4.BeautifulSoup(page_source, "lxml")
last_page_url = soup.find_all("a", string="Last")[0]['href']
last_page = int(last_page_url[last_page_url.find('=')+1:])

# %%
# scrape all pages
df_gali_all = pd.DataFrame()
for page in range(last_page):
    url = 'https://www.galidata.org/accelerators/directory/?page=%d' % (page + 1)
    df_temp = extract_gali(url)
    df_gali_all = df_gali_all.append(df_temp)
df_gali_all = df_gali_all.reset_index(drop=True)
df_gali_all.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_gali_all, df_data_counter, 'location', exact_match=False)

# %% [markdown]
# ## Companiesss.com
# Stopped since server was marked as too busy :(

# %%
country = 'Senegal'
data_source = '[PARTIAL] Companiess (companies)'

# %%
df_companiesss_all = pd.DataFrame()

# %%
# define country subdomain
base_url = 'https://www.companiess.com'
append_url_cou = '/%s-country.html' % str.lower(country)

# identify last page
r = requests.get(base_url + append_url_cou)
page_source = r.content
soup = bs4.BeautifulSoup(page_source, "lxml")
last_page_url = soup.find_all("a", string="Last")[0]['href']
last_page = int(last_page_url[last_page_url.find('p')+1:last_page_url.find('.html')])

# %%
dict_companiesss = {}

# go through all pages
for page in range(last_page):
    page_url = 'https://www.companiess.com/%s-country/p%d.html' % (str.lower(country), page + 1)
    
    r = requests.get(page_url)
    page_source = r.content
    soup = bs4.BeautifulSoup(page_source, "lxml")
    
    # get full directory list from current page
    dir_list = soup.find('div', {'class':'results'})

    
    for dir_entry in dir_list.find_all('dt'):
        name = dir_entry.find('a')['title']
        append_url = dir_entry.find('a')['href']
        dict_companiesss[name] = {'dir_url': base_url + append_url}

# %%
# extract data from all company pages
for name in dict_companiesss.keys():
    url = dict_companiesss[name]['dir_url']

    try:
        r = requests.get(url)
    except:
        time.sleep(5)
        r = requests.get(url)

    page_source = r.content
    soup = bs4.BeautifulSoup(page_source, "lxml")

    # pull company information
    soup_info = soup.find('div', {'class':'info'})
    for info_attribute in soup_info.find_all('li'):
        info_attribute_type = info_attribute.find('span').getText()
        info_attribute_type = info_attribute_type.replace(":",'')

        if info_attribute_type == 'Website':
            temp_url = base_url + info_attribute.find("a")['href']
            try:
                temp_r = requests.get(temp_url)
                info_attribute_value = temp_r.url
            except:
                info_attribute_value = np.nan
        else:
            info_attribute.span.clear()
            info_attribute_value = info_attribute.getText()

        dict_companiesss[name][info_attribute_type] = info_attribute_value

    # pull company description
    soup_desc = soup.find('div', {'class':'desc'})
    if soup_desc.getText().strip() == '':
        dict_companiesss[name]['company_description'] = np.nan
    else:
        soup_desc.h3.clear()
        dict_companiesss[name]['company_description'] = soup_desc.getText().strip()

    # pull company products
    soup_product = soup.find('div', {'class':'desc-product'})

    if soup_product.getText().strip() == '':
        dict_companiesss[name]['product_list'] = np.nan
    else:
        soup_product.h3.clear()
        product_list = []
        for prod in soup_product.find_all('li'):
            product_list.append(prod.getText())

        dict_companiesss[name]['product_list'] = product_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-487-cb0812335580> in <module>()
#      14     # pull company information
#      15     soup_info = soup.find('div', {'class':'info'})
# ---> 16     for info_attribute in soup_info.find_all('li'):
#      17         info_attribute_type = info_attribute.find('span').getText()
#      18         info_attribute_type = info_attribute_type.replace(":",'')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
df_companiesss_cou = pd.DataFrame(dict_companiesss).T.reset_index()
df_companiesss_cou['country'] = country

# %%
df_companiesss_all = df_companiesss_all.append(df_companiesss_cou)

# %%
df_companiesss_all.to_csv(os.path.join(output_folder, cou,"%s - %s - %s.csv" % (date_today, data_source, country)), index=False)

# %% [markdown]
# ## Yellow Pages of Africa
# http://www.yellowpagesofafrica.com/country/senegal/

# %%
# df_ypa_senegal = df_ypa_cou_topic.copy()
df_ypa_senegal = extract_ypa_country('Senegal', date_today)
df_ypa_kenya = extract_ypa_country('Kenya', date_today)
df_ypa_nigeria = extract_ypa_country('Nigeria', date_today)

# %%
# concatenate and save to raw
df_ypa_all = pd.concat([df_ypa_senegal, df_ypa_kenya, df_ypa_nigeria]).reset_index()
df_ypa_all.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
data_source = 'Yellow Pages of Africa (companies)'
df_data_counter = update_data_counter(data_source, country_list, df_ypa_all, df_data_counter, 'country', exact_match=True)

# %% [markdown]
# # Extract company list data - Asia

# %% [markdown]
# ## Companiess.com
# Stopped since server was marked as too busy :(

# %%
df_companiesss_all = pd.DataFrame()

# %%
df_companiesss_all.shape
# Out:
# (25308, 3)

# %%
data_source = '[PARTIAL] Companiess (companies)'

# %%
for country in ['Kenya', 'Nigeria', 'Vietnam']:
    # define country subdomain
    base_url = 'https://www.companiess.com'
    append_url_cou = '/%s-country.html' % str.lower(country)

    # identify last page
    r = requests.get(base_url + append_url_cou)
    page_source = r.content
    soup = bs4.BeautifulSoup(page_source, "lxml")
    last_page_url = soup.find_all("a", string="Last")[0]['href']
    last_page = int(last_page_url[last_page_url.find('p')+1:last_page_url.find('.html')])

    dict_companiesss = {}

    # go through all pages
    for page in range(last_page):
        page_url = 'https://www.companiess.com/%s-country/p%d.html' % (str.lower(country), page + 1)

        r = requests.get(page_url)
        page_source = r.content
        soup = bs4.BeautifulSoup(page_source, "lxml")

        # get full directory list from current page
        dir_list = soup.find('div', {'class':'results'})


        for dir_entry in dir_list.find_all('dt'):
            name = dir_entry.find('a')['title']
            append_url = dir_entry.find('a')['href']
            dict_companiesss[name] = {'dir_url': base_url + append_url}

    df_companiesss_cou = pd.DataFrame(dict_companiesss).T.reset_index()
    df_companiesss_cou['country'] = country

    df_companiesss_all = df_companiesss_all.append(df_companiesss_cou)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-200-21ce180b525e> in <module>()
#      25
#      26
# ---> 27         for dir_entry in dir_list.find_all('dt'):
#      28             name = dir_entry.find('a')['title']
#      29             append_url = dir_entry.find('a')['href']
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# # extract data from all company pages
# for name in dict_companiesss.keys():
#     url = dict_companiesss[name]['dir_url']

#     try:
#         r = requests.get(url)
#     except:
#         time.sleep(5)
#         r = requests.get(url)

#     page_source = r.content
#     soup = bs4.BeautifulSoup(page_source, "lxml")

#     # pull company information
#     soup_info = soup.find('div', {'class':'info'})
#     for info_attribute in soup_info.find_all('li'):
#         info_attribute_type = info_attribute.find('span').getText()
#         info_attribute_type = info_attribute_type.replace(":",'')

#         if info_attribute_type == 'Website':
#             temp_url = base_url + info_attribute.find("a")['href']
#             try:
#                 temp_r = requests.get(temp_url)
#                 info_attribute_value = temp_r.url
#             except:
#                 info_attribute_value = np.nan
#         else:
#             info_attribute.span.clear()
#             info_attribute_value = info_attribute.getText()

#         dict_companiesss[name][info_attribute_type] = info_attribute_value

#     # pull company description
#     soup_desc = soup.find('div', {'class':'desc'})
#     if soup_desc.getText().strip() == '':
#         dict_companiesss[name]['company_description'] = np.nan
#     else:
#         soup_desc.h3.clear()
#         dict_companiesss[name]['company_description'] = soup_desc.getText().strip()

#     # pull company products
#     soup_product = soup.find('div', {'class':'desc-product'})

#     if soup_product.getText().strip() == '':
#         dict_companiesss[name]['product_list'] = np.nan
#     else:
#         soup_product.h3.clear()
#         product_list = []
#         for prod in soup_product.find_all('li'):
#             product_list.append(prod.getText())

#         dict_companiesss[name]['product_list'] = product_list

# %%
df_companiesss_all['country'].value_counts()
# Out:
# Indonesia    25308
# Nigeria       6020
# Kenya         3026
# Name: country, dtype: int64

# %%
df_companiesss_all.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# %%
# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_companiesss_all, df_data_counter, 'country', exact_match=True)

# %% [markdown]
# ## Endeavor Indonesia

# %%
def extract_endeavor_persons(soup, endeavor_persons_dict):
    for entrep in soup.find_all("div", {"class": "e-filtered-item"}):
    # entrep = soup.find_all("div", {"class": "e-filtered-item"})[0]

        person_url = entrep.find("a", {"class": "e-filtered-img"})['href']
        person_photo = entrep.find("img")['src']
        person_name = entrep.find("a",{"class": "e-filtered-tit"}).getText()
        person_company = entrep.find("div").getText().strip()

        endeavor_persons_dict[person_name] = {'founder_url': person_url, 'founder_photo': person_photo, 'company_name': person_company}
    
    return(endeavor_persons_dict)

# %%
data_source = 'Endeavor (companies, entrepreneurs)'
root_url = 'http://endeavorindonesia.org/category/entrepreneur/'

r = requests.get(root_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# get all pages
endeavor_pages_list = []
for page in soup.find_all("a", {"class": "page"}):
    endeavor_pages_list.append(page['href'])

# %%
# initialize empty dict
endeavor_persons_dict = {}

# extract first page of endeavor persons
endeavor_persons_dict = extract_endeavor_persons(soup, endeavor_persons_dict)

# extract remaining pages of endeavor persons
for root_url in endeavor_pages_list:
    r = requests.get(root_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")
    endeavor_persons_dict = extract_endeavor_persons(soup, endeavor_persons_dict)

# %%
for person_name in list(endeavor_persons_dict.keys()):
    # get information from the person's endeavor page
    person_url = endeavor_persons_dict[person_name]['founder_url']
    r = requests.get(person_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    # get main sections
    company_desc = soup.find("div", {"class": "e-header uk-grid uk-grid-medium"})
    company_writeup_section = soup.find("div", {"class": "entry-content e-content"})

    # get important data from company_desc
    endeavor_persons_dict[person_name]['company_industry'] = company_desc.find('span', {'class': 'uk-text-bold'}).next_element.next_element.strip()
    endeavor_persons_dict[person_name]['company_logo'] = company_desc.find('img')['src']
    try:
        endeavor_persons_dict[person_name]['company_url'] = company_desc.find('a', {"class":"uk-icon-globe"})['href']
    except:
        pass
    try:
        endeavor_persons_dict[person_name]['company_socmed_twitter'] = company_desc.find('a', {"class":"uk-icon-twitter"})['href']
    except:
        pass
    try:
        endeavor_persons_dict[person_name]['company_socmed_instagram'] = company_desc.find('a', {"class":"uk-icon-instagram"})['href']
    except:
        pass
    try:
        endeavor_persons_dict[person_name]['company_socmed_linkedin'] = company_desc.find('a', {"class":"uk-icon-linkedin"})['href']
    except:
        pass
    # get important data from company_writeup_section
    endeavor_persons_dict[person_name]['company_writeup'] = company_writeup_section.getText().strip()

    if company_writeup_section.find('ul'):
        company_links = {}
        for link in company_writeup_section.find('ul').find_all('li'):
            company_links[link.getText()] = link.find('a')['href']
        endeavor_persons_dict[person_name]['company_links'] = company_links
    else:
        endeavor_persons_dict[person_name]['company_links'] = np.nan

# %%
# create dataframe of endeavor eprsons
df_endeavor = pd.DataFrame.from_dict(endeavor_persons_dict, orient='index')
cols = list(df_endeavor.columns)
cols = ['founder_name'] + cols

df_endeavor = df_endeavor.reset_index()
df_endeavor.columns = cols
df_endeavor['country'] = 'Indonesia'

# %%
# export
df_endeavor.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_endeavor, df_data_counter, 'country', exact_match=True)

# %%
df_data_counter
# Out:
#                            data_source number_of_extracted_cols Senegal  \
# 0  Endeavor (companies, entrepreneurs)                       13       0
# 1              Companiesss (companies)                        3       0
# 2    [PARTIAL] Companiesss (companies)                        3       0
#
#   Indonesia Vietnam Kenya Nigeria
# 0        40       0     0       0
# 1     25308       0     0       0
# 2     25308       0  3026    6020

# %% [markdown]
# ## GBG indonesia
# http://www.gbgindonesia.com/directory/index.php

# %%
def extract_gbg_indonesia(page_num, gbg_entities_dict):

    root_url = 'http://www.gbgindonesia.com/directory/search.php?s=&s1=&sr=&o=&l=&r=&page=%d&lng=en' % page_num
    r = requests.get(root_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    # get max page shown
    if soup.find('ul', {'class':'pagination'}):
        page_list = [page_val.getText() for page_val in soup.find('ul', {'class':'pagination'}).find_all('li')]
        max_page_shown = max([int(page_val) for page_val in page_list if page_val not in ['Prev', 'Next']])
        
    # pull each entity result
    for entity_result in soup.find_all("div", {"class": "search-result"}):
        entity_name = entity_result.find("span", {"class": "directory_name"}).getText().strip()
        gbg_entities_dict[entity_name] = {}

        # get attributes per entity result
        gbg_entities_dict[entity_name]['entity_logo_url'] = entity_result.find("img")['src']
        try:
            gbg_entities_dict[entity_name]['entity_industry'] = entity_result.find("span", {"class": "fa-folder-open"}).next_element.getText()
        except:
            pass
        try:
            gbg_entities_dict[entity_name]['entity_location'] = entity_result.find("span", {"class": "fa-map-marker"}).next_element.strip()
        except:
            pass
        gbg_entities_dict[entity_name]['entity_description'] = entity_result.find("div", {"class": "directory-description"}).getText().strip()

        gbg_entities_dict[entity_name]['entity_subindustry_list'] = [val.getText() for val in entity_result.find_all("li", {"class": "opportunites-li key-list"})]
        gbg_entities_dict[entity_name]['entity_product_list'] = [val.getText() for val in entity_result.find_all(lambda tag: tag.name == 'li' and tag.get('class') == ['key-list'])]
        gbg_entities_dict[entity_name]['entity_url'] = entity_result.find("span", {"class": "fa-globe"}).parent['href']
        
    return(gbg_entities_dict, max_page_shown)

# %%
data_source = 'GBG Indonesia (companies)'

# initialize
gbg_entities_dict = {}
page_num = 1

root_url = 'http://www.gbgindonesia.com/directory/search.php?s=&s1=&sr=&o=&l=&r=&page=%d&lng=en' % page_num
r = requests.get(root_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# get max page shown
if soup.find('ul', {'class':'pagination'}):
    page_list = [page_val.getText() for page_val in soup.find('ul', {'class':'pagination'}).find_all('li')]
    max_page_shown = max([int(page_val) for page_val in page_list if page_val not in ['Prev', 'Next']])

# %%
while page_num < max_page_shown:
    print("Downloading %d with max page shown %d" % (page_num, max_page_shown))
    gbg_entities_dict, max_page_shown = extract_gbg_indonesia(page_num, gbg_entities_dict)
    print("Extracted a cumulative of %d entities" % (len(list(gbg_entities_dict.keys()))))
    page_num += 1
# Out:
# ...
# Extracted a cumulative of 10 entities
# ...
# Extracted a cumulative of 20 entities
# ...
# Extracted a cumulative of 30 entities
# ...
# Extracted a cumulative of 40 entities
# ...
# Extracted a cumulative of 50 entities
# ...
# Extracted a cumulative of 60 entities
# ...
# Extracted a cumulative of 70 entities
# ...
# Extracted a cumulative of 80 entities
# ...
# Extracted a cumulative of 90 entities
# ...
# Extracted a cumulative of 100 entities
# ...
# Extracted a cumulative of 110 entities
# ...
# Extracted a cumulative of 120 entities
# ...
# Extracted a cumulative of 130 entities
# ...
# Extracted a cumulative of 140 entities
# ...
# Extracted a cumulative of 150 entities
# ...
# Extracted a cumulative of 160 entities
# ...
# Extracted a cumulative of 170 entities
# ...
# Extracted a cumulative of 180 entities
# ...
# Extracted a cumulative of 190 entities
# ...
# Extracted a cumulative of 200 entities
# ...
# Extracted a cumulative of 210 entities
# ...
# Extracted a cumulative of 220 entities
# ...
# Extracted a cumulative of 230 entities
# ...
# Extracted a cumulative of 240 entities
# ...

# %%
# create dataframe of endeavor eprsons
df_gbg_indonesia = pd.DataFrame.from_dict(gbg_entities_dict, orient='index')
cols = list(df_gbg_indonesia.columns)
cols = ['entity_name'] + cols

df_gbg_indonesia = df_gbg_indonesia.reset_index()
df_gbg_indonesia.columns = cols
df_gbg_indonesia['country'] = 'Indonesia'

# %%
# export
df_gbg_indonesia.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_gbg_indonesia, df_data_counter, 'country', exact_match=True)

# %%
df_data_counter
# Out:
#                            data_source number_of_extracted_cols Senegal  \
# 0  Endeavor (companies, entrepreneurs)                       13       0
# 1              Companiesss (companies)                        3       0
# 2    [PARTIAL] Companiesss (companies)                        3       0
# 3            GBG Indonesia (companies)                        9       0
#
#   Indonesia Vietnam Kenya Nigeria
# 0        40       0     0       0
# 1     25308       0     0       0
# 2     25308       0  3026    6020
# 3       574       0     0       0

# %% [markdown]
# ## 1000 Startup Digital
# https://1000startupdigital.id/mentors/id/

# %%
data_source = '1000 Startup Digital (mentors, entrepreneurs)'
root_url = 'https://1000startupdigital.id/mentors/id/'

r = requests.get(root_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# %%
mentor_dict = {}
for mentor in soup.find("div", {"class": "container"}).find_all("div", {"class": "col-md-3 nopad"}):
# mentor = soup.find("div", {"class": "container"}).find_all("div", {"class": "col-md-3 nopad"})[0]
    mentor_name = mentor.find("h3").getText()
    mentor_dict[mentor_name] = {}
    mentor_position_company = mentor.find("h4").getText()
    mentor_position_company_list = mentor_position_company.split(', ')

    mentor_dict[mentor_name]['mentor_position_company'] = mentor_position_company
    try:
        mentor_dict[mentor_name]['mentor_position'] = mentor_position_company_list[0]
    except:
        pass
    try:
        mentor_dict[mentor_name]['mentor_company'] = mentor_position_company_list[1]
    except:
        pass

# %%
# create dataframe of endeavor eprsons
df_1000startups = pd.DataFrame.from_dict(mentor_dict, orient='index')
cols = list(df_1000startups.columns)
cols = ['mentor_name'] + cols

df_1000startups = df_1000startups.reset_index()
df_1000startups.columns = cols
df_1000startups['country'] = 'Indonesia'

# %%
# export
df_1000startups.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_1000startups, df_data_counter, 'country', exact_match=True)

# %%
df_data_counter
# Out:
#                                      data_source number_of_extracted_cols  \
# 0            Endeavor (companies, entrepreneurs)                       13
# 1                        Companiesss (companies)                        3
# 2              [PARTIAL] Companiesss (companies)                        3
# 3                      GBG Indonesia (companies)                        9
# 4  1000 Startup Digital (mentors, entrepreneurs)                        5
#
#   Senegal Indonesia Vietnam Kenya Nigeria
# 0       0        40       0     0       0
# 1       0     25308       0     0       0
# 2       0     25308       0  3026    6020
# 3       0       574       0     0       0
# 4       0       197       0     0       0

# %% [markdown]
# ## Compass List
# startups: https://compasslist.com/startups?country[]=ID&sectors[]=110&type[]=7
#
# investors: https://compasslist.com/investors?country[]=ID&stage[]=7&sectors[]=110&type[]=2

# %%
def get_compasslist_data(entity_type="startups", cou_iso2="", page_val=1):
    # create base URLs
    base_url = 'https://compasslist.com/%s' + entity_type
    referrer_url = base_url % ('')
    get_url = base_url % ('ajax-') + '?page=%d' % (page_val)
                
    headers = {
    'Host': 'compasslist.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:62.0) Gecko/20100101 Firefox/62.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br',
    'Referer': referrer_url, 
    'X-Requested-With': 'XMLHttpRequest',
    'Connection': 'keep-alive',
    'TE': 'Trailers'
    }

    soup = bs4.BeautifulSoup(requests.get(get_url, headers=headers).content, "lxml")
    
    return(soup)

# %%
country = 'Indonesia'
cou, cou_iso2, cou_iso3, cou_capitalCity, cou_geo = extract_cou_metadata(df_countries, cou=country)

# %% [markdown]
# ### OLD code

# %%
# def get_compasslist_data(entity_type="startups", cou_iso2="", sector_val=np.nan, stage_val=np.nan, investor_type_val=np.nan):
#     # create base URLs
#     base_url = 'https://compasslist.com/%s' + entity_type + "?"
#     referrer_url = base_url % ('')
#     get_url = base_url % ('ajax-')
    
#     params_list = []
    
#     # append the parameters
#     if cou_iso2 != "":
#         params_list.append('country[]=%s' % cou_iso2)
        
#     if not np.isnan(sector_val):
#         params_list.append('sectors[]=%d' % sector_val)    
    
#     # append parameters based on entity type
    
#     if not np.isnan(stage_val):
#         if entity_type == 'startups':
#             params_list.append('type[]=%d' % stage_val) 
#         elif entity_type == 'investors':
#             params_list.append('stage[]=%d' % stage_val) 
            
#     if not np.isnan(investor_type_val):
#         if entity_type == 'investors':
#             params_list.append('type[]=%d' % investor_type_val)  
            
#     referrer_url += '&'.join(params_list)
#     get_url += '&'.join(params_list) + '&page=false'
    
#     headers = {
#     'Host': 'compasslist.com',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:62.0) Gecko/20100101 Firefox/62.0',
#     'Accept': '*/*',
#     'Accept-Language': 'en-US,en;q=0.5',
#     'Accept-Encoding': 'gzip, deflate, br',
#     'Referer': referrer_url, 
#     'X-Requested-With': 'XMLHttpRequest',
#     'Connection': 'keep-alive',
#     'TE': 'Trailers'
#     }

#     soup = bs4.BeautifulSoup(requests.get(get_url, headers=headers).content, "lxml")
    
#     return(soup)

# %%
# # initial values from manual checks. we automate updating these.
# sector_max = 110
# stage_max = 7
# investor_type_max = 2

# %%
# # check if the max values hold
# soup = get_compasslist_data(entity_type="startups", cou_iso2=cou_iso2, sector_val=sector_max+1)
# entries_len = len(soup.find_all("div", {"class": "discover-grid"}))

# while entries_len > 0:
#     sector_max += 1
#     soup = get_compasslist_data(entity_type="startups", cou_iso2=cou_iso2, stage_val=sector_max)
#     entries_len = len(soup.find_all("div", {"class": "discover-grid"}))

# print(sector_max)
# Out:
# 110

# %%
# # check if the max values hold
# soup = get_compasslist_data(entity_type="startups", cou_iso2=cou_iso2, stage_val=stage_max+1)
# entries_len = len(soup.find_all("div", {"class": "discover-grid"}))

# while entries_len > 0:
#     stage_max += 1
#     soup = get_compasslist_data(entity_type="startups", cou_iso2=cou_iso2, stage_val=stage_max)
#     entries_len = len(soup.find_all("div", {"class": "discover-grid"}))

# print(stage_max)
# Out:
# 7

# %%
# # check if the max values hold
# soup = get_compasslist_data(entity_type="investors", cou_iso2='ID', investor_type_val=investor_type_max+1)
# entries_len = len(soup.find_all("div", {"class": "discover-grid"}))

# while entries_len > 0:
#     investor_type_max += 1
#     soup = get_compasslist_data(entity_type="investors", cou_iso2='ID', investor_type_val=investor_type_max)
#     entries_len = len(soup.find_all("div", {"class": "discover-grid"}))

# print(investor_type_max)
# Out:
# 2

# %% [markdown]
# ### Startups

# %%
entity_type = 'startups'
soup = get_compasslist_data(entity_type=entity_type, cou_iso2=cou_iso2)
entity_page_max = max([int(page.getText()) for page in soup.find("ul", {'class':'pagination'}).find_all('li') if page.getText().isdigit()])

# %%
entity_dict = {}
for page_val in range(1, entity_page_max+1):
# page_val = 1
    # pull data
    soup = get_compasslist_data(entity_type=entity_type, cou_iso2=cou_iso2, page_val=page_val)

    # get key table
    entity_list = soup.find_all("div", {"class": "discover-grid"})
    entries_len = len(entity_list)

    # grab data if there are contents
    if entries_len > 0:
        for entity_entry in entity_list:
        # entity_entry = entity_list[0]

            entity_name = entity_entry.find('h4').getText().strip()
            entity_dict[entity_name] = {}
            entity_dict[entity_name]['entity_dir_url'] = entity_entry.find('h4').parent['href']
            entity_dict[entity_name]['entity_logo'] = entity_entry.find("img", {"class": "img-responsive"})['src']
            entity_dict[entity_name]['entity_desc'] = entity_entry.find("p", {"class":"text-left"}).getText().strip()
            entity_dict[entity_name]['entity_country_iso2'] = entity_entry.find('label', string=' Country: ').parent.find('span')['data-country']
            entity_dict[entity_name]['entity_industry_list'] = [a.getText().strip() for a in entity_entry.find("label", string=' Sectors: ').parent.find('div').find_all('a')]
            entity_dict[entity_name]['entity_funding_stage'] = entity_entry.find("label", string=' Funding Stage: ').parent.find('a').getText().strip()

# %%
entity_dict_startups = entity_dict.copy()

# %%
df_compasslist_startups = pd.DataFrame.from_dict(entity_dict_startups, orient='index')
df_compasslist_startups['entity_type'] = 'startup'

# %% [markdown]
# ### Investors

# %%
entity_type = 'investors'
soup = get_compasslist_data(entity_type=entity_type, cou_iso2=cou_iso2)
entity_page_max = max([int(page.getText()) for page in soup.find("ul", {'class':'pagination'}).find_all('li') if page.getText().isdigit()])
print(entity_page_max)
# Out:
# 64

# %%
entity_dict = {}
for page_val in range(1, entity_page_max+1):
    
    # pull data
    soup = get_compasslist_data(entity_type=entity_type, cou_iso2=cou_iso2, page_val=page_val)    
    # get key table
    entity_list = soup.find_all("div", {"class": "discover-grid"})
    entries_len = len(entity_list)
    
    print("pulling %d entities from page %d" % (entries_len, page_val))
    
    # grab data if there are contents
    if entries_len > 0:
        for entity_entry in entity_list:
        # entity_entry = entity_list[0]

            entity_name = entity_entry.find('h4').getText().strip()
            entity_dict[entity_name] = {}

            entity_dict[entity_name]['entity_dir_url'] = entity_entry.find('h4').parent['href']
            entity_dict[entity_name]['entity_logo'] = entity_entry.find("img", {"class": "img-responsive"})['src']
            entity_dict[entity_name]['entity_desc'] = entity_entry.find("p").getText().strip()
            try:
                entity_dict[entity_name]['entity_country_iso2'] = entity_entry.find('label', string=' Headquarters: ').parent.find('span')['data-country']
            except:
                entity_dict[entity_name]['entity_country_iso2'] = ''
            try:
                entity_dict[entity_name]['entity_industry_list'] = [a.getText().strip() for a in entity_entry.find("label", string=' Investment Focus: ').parent.find('div').find_all('a')]
            except:
                entity_dict[entity_name]['entity_industry_list'] = []
            try:
                entity_dict[entity_name]['entity_funding_stage'] = [a.getText().strip() for a in entity_entry.find("label", string=' Investment Stage: ').parent.find('div').find_all('a')]
            except:
                entity_dict[entity_name]['entity_funding_stage'] = []
# Out:
# pulling 10 entities from page 1
# pulling 10 entities from page 2
# pulling 9 entities from page 3
# pulling 10 entities from page 4
# pulling 10 entities from page 5
# pulling 10 entities from page 6
# pulling 10 entities from page 7
# pulling 10 entities from page 8
# pulling 10 entities from page 9
# pulling 10 entities from page 10
# pulling 10 entities from page 11
# pulling 10 entities from page 12
# pulling 10 entities from page 13
# pulling 10 entities from page 14
# pulling 10 entities from page 15
# pulling 10 entities from page 16
# pulling 10 entities from page 17
# pulling 10 entities from page 18
# pulling 10 entities from page 19
# pulling 10 entities from page 20
# pulling 10 entities from page 21
# pulling 10 entities from page 22
# pulling 10 entities from page 23
# pulling 10 entities from page 24
# pulling 10 entities from page 25
# pulling 10 entities from page 26
# pulling 10 entities from page 27
# pulling 10 entities from page 28
# ...

# %%
df_compasslist_investors = pd.DataFrame.from_dict(entity_dict, orient='index')
df_compasslist_investors['entity_type'] = entity_type

# %% [markdown]
# ### Merge directory

# %%
df_compasslist_directory = pd.concat([df_compasslist_startups, df_compasslist_investors])

cols = list(df_compasslist_directory.columns)
cols = ['entity_name'] + cols

df_compasslist_directory = df_compasslist_directory.reset_index()
df_compasslist_directory.columns = cols

# %%
df_countries_iso2 = df_countries_all[['name', 'iso2']]
df_countries_iso2.columns = ['entity_country', 'entity_country_iso2']

# %%
df_compasslist_directory = df_compasslist_directory.merge(df_countries_iso2, how='left', on='entity_country_iso2')

# %%
df_compasslist_directory.groupby(['entity_country', 'entity_type']).size()
# Out:
# entity_country        entity_type
# Andorra               investors        1
# Argentina             investors        1
# Australia             investors        3
# Chile                 investors        1
# China                 investors      307
#                       startup        139
# Denmark               investors        1
# Estonia               investors        1
# France                investors        6
# Germany               investors        9
# Hong Kong SAR, China  investors       11
# India                 investors        5
# Indonesia             investors       63
#                       startup        120
# Japan                 investors       22
# Korea, Rep.           investors       10
# Malaysia              investors        3
# Mexico                investors        3
# Netherlands           investors        1
# Portugal              investors       26
#                       startup         33
# Russian Federation    investors        2
# ...

# %%
data_source = 'Compass List Directory (startups, investors)'

# %%
# export
df_compasslist_directory.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_compasslist_directory, df_data_counter, 'entity_country', exact_match=True)

# %%
df_data_counter
# Out:
#                                     data_source number_of_extracted_cols  \
# 0  Compass List Directory (startups, investors)                        9
#
#   Senegal Indonesia Vietnam Kenya Nigeria
# 0       0       183       0     0       0

# %% [markdown]
# ### Scrape Indonesian startup pages

# %%
# get only startups in pilot countries
df_compasslist_startups_pilots = df_compasslist_directory[(df_compasslist_directory['entity_type'] == 'startup') & (df_compasslist_directory['entity_country'].isin(country_list))].reset_index(drop=True).copy()

# %%
# initialize dictionaries
compasslist_startups_pilots_dict = df_compasslist_startups_pilots.set_index('entity_name').to_dict(orient='index')
compasslist_startups_founders_dict = {}

# %%
for entity_name in list(compasslist_startups_pilots_dict.keys()):
# entity_name = list(compasslist_startups_pilots_dict.keys())[0]
    entity_dir_url = compasslist_startups_pilots_dict[entity_name]['entity_dir_url']
    print(entity_name, entity_dir_url)

    # get sections of pulled page source
    soup = bs4.BeautifulSoup(requests.get(entity_dir_url, headers=headers).content, "lxml")
    sidebar_section = soup.find("div", {"class":"sidebar"})
    timeline_section = soup.find("div", {"id":"timeline"})

    # get information needed per startup
    compasslist_startups_pilots_dict[entity_name]['entity_province'] = soup.find('i', {'class':'fa-location-arrow'}).parent.getText().strip()
    try:
        compasslist_startups_pilots_dict[entity_name]['entity_url'] = soup.find('a', string=' Website ')['href']
    except:
        pass

    compasslist_startups_pilots_dict[entity_name]['entity_desc_pitch'] = soup.find('h5', {"class":"pitch-content"}).getText().strip()
    compasslist_startups_pilots_dict[entity_name]['entity_desc_why'] = soup.find('h5', {"class":"highlight"}, string='  WHY? ').parent.getText().strip()
    compasslist_startups_pilots_dict[entity_name]['entity_desc_market'] = soup.find('h5', {"class":"highlight"}, string='   MARKET ').parent.getText().strip()
    compasslist_startups_pilots_dict[entity_name]['entity_desc_product'] = soup.find('h5', string=' PRODUCT ').parent.getText().strip()
    compasslist_startups_pilots_dict[entity_name]['entity_desc_business_model'] = soup.find('h5', string=' BUSINESS MODEL ').parent.getText().strip()

    compasslist_startups_pilots_dict[entity_name]['entity_timeline_list'] = [val.getText().strip() for val in timeline_section.find("ul", {'id':"g_timeline"}).find_all('div', {'class':'timeline-panel'})]
    compasslist_startups_pilots_dict[entity_name]['entity_launch_year'] = min([int(a.strip()) for a in entity_timeline_list[0][:10].split(' ') if a.isdigit()])
    compasslist_startups_pilots_dict[entity_name]['entity_investor_list'] = [investor_li.getText().strip() for investor_li in sidebar_section.find('h5', string=' INVESTORS ').findNext('ul').find_all('div', {'style':"margin-top:5px;"})]
    compasslist_startups_pilots_dict[entity_name]['entity_founder_list'] = [investor_li.getText().strip() for investor_li in sidebar_section.find('h5', string=' FOUNDERS ').findNext('ul').find_all('h4')]

    # get founders
    founders_list = sidebar_section.find('h5', string=' FOUNDERS ').findNext('ul').find_all('div', {'style':"margin-top:5px;"})

    for founder in founders_list:
        founder_name = founder.find('h4').getText().strip()
        compasslist_startups_founders_dict[founder_name] = {}
        compasslist_startups_founders_dict[founder_name]['entity_type'] = 'entrepreneur'
        compasslist_startups_founders_dict[founder_name]['entity_subtype'] = 'founder'
        compasslist_startups_founders_dict[founder_name]['entity_photo'] = founder.find('img')['src']
        compasslist_startups_founders_dict[founder_name]['entity_dir_url'] = founder.find('a')['href']
        compasslist_startups_founders_dict[founder_name]['entity_position'] = founder.find('div').getText().strip()
        compasslist_startups_founders_dict[founder_name]['entity_company'] = entity_name
# Out:
# 8villages https://compasslist.com/startup/252_8villages
# Adskom https://compasslist.com/startup/94_adskom
# Ahlijasa https://compasslist.com/startup/167_ahlijasa
# Airy Rooms https://compasslist.com/startup/224_airy-rooms
# Alkemis Games https://compasslist.com/startup/81_alkemis-games
# Alodokter https://compasslist.com/startup/209_alodokter
# Amartha https://compasslist.com/startup/245_amartha
# Angon https://compasslist.com/startup/297_angon
# Arsitag https://compasslist.com/startup/84_arsitag
# Aruna https://compasslist.com/startup/188_aruna
# Astronaut Technologies https://compasslist.com/startup/240_astronaut-technologies
# Bareksa https://compasslist.com/startup/300_bareksa
# Berrybenka https://compasslist.com/startup/89_berrybenka
# BlackGarlic https://compasslist.com/startup/168_blackgarlic
# Bobobobo https://compasslist.com/startup/18_bobobobo
# Botika https://compasslist.com/startup/244_botika
# Bridestory https://compasslist.com/startup/19_bridestory
# ...

# %%
df_compasslist_founders = pd.DataFrame.from_dict(compasslist_startups_founders_dict, orient='index')
df_compasslist_founders['entity_company_country'] = 'Indonesia'

# %%
cols = list(df_compasslist_founders.columns)
cols = ['entity_name'] + cols

df_compasslist_founders = df_compasslist_founders.reset_index()
df_compasslist_founders.columns = cols

# %%
data_source = 'Compass List Directory (founders)'

# %%
# export
df_compasslist_founders.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)
# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_compasslist_founders, df_data_counter, 'entity_company_country', exact_match=True)

# %%
df_compasslist_startup_data = pd.DataFrame.from_dict(compasslist_startups_pilots_dict, orient='index')
cols = list(df_compasslist_startup_data.columns)
cols = ['entity_name'] + cols

df_compasslist_startup_data = df_compasslist_startup_data.reset_index()
df_compasslist_startup_data.columns = cols

# %%
data_source = 'Compass List profiles (startups)'

# %%
# export
df_compasslist_startup_data.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)
# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_compasslist_startup_data, df_data_counter, 'entity_country', exact_match=True)

# %%
df_data_counter
# Out:
#                                     data_source number_of_extracted_cols  \
# 0  Compass List Directory (startups, investors)                        9
# 1             Compass List Directory (founders)                        8
# 2              Compass List profiles (startups)                       20
#
#   Senegal Indonesia Vietnam Kenya Nigeria
# 0       0       183       0     0       0
# 1       0       278       0     0       0
# 2       0       120       0     0       0

# %% [markdown]
# ## Startup Ranking
# https://www.startupranking.com/top/indonesia/1

# %%
base_url = 'https://www.startupranking.com'
scraper = cfscrape.create_scraper()  # returns a CloudflareScraper instance

# create initial dictionaries
entity_dict = {}
investors_dict = {}
founders_dict = {}

# %%
# initialize
for country in country_list:
    print("Downloading %s" % (country))
    page_num = 1
    dir_url = '/top/%s/%d' % (str.lower(country), page_num)

    r = scraper.get(base_url + dir_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    # continue scraping while there is a "Load Next button"
    while soup.find("button", string="Load Next"):

        entity_list = soup.find("table", {"class": "rank_table"}).find("tbody").find_all('tr')
        entity_type = 'startup'

        print("Downloading page %d with %d entities" % (page_num, len(entity_list)))
        if len(entity_list) > 0:
            entity_dict = extract_startupranking_directory(entity_list, entity_dict)

        page_num += 1

        dir_url = '/top/%s/%d' % (str.lower(country), page_num)
        r = scraper.get(base_url + dir_url)
        soup = bs4.BeautifulSoup(r.content, "lxml")

    entity_list = soup.find("table", {"class": "rank_table"}).find("tbody").find_all('tr')
    entity_type = 'startup'

    print("Downloading page %d with %d entities" % (page_num, len(entity_list)))
    if len(entity_list) > 0:
        entity_dict = extract_startupranking_directory(entity_list, entity_dict)
        
    # first scraping of startup company pages
    entity_dict, investors_dict, founders_dict = extract_startupranking_company_data(scraper, entity_dict, investors_dict, founders_dict)

    # scraping investor company pages
    investors_dict, investors_dict, founders_dict = extract_startupranking_company_data(scraper, investors_dict, investors_dict, founders_dict)
    print("Downloaded %d investors" % (len(list(investors_dict.keys()))))

    # scraping founder pages
    founders_dict = extract_startupranking_founder_data(scraper, founders_dict)
    print("Downloaded %d founders" % (len(list(founders_dict.keys()))))
    print("======================")
# Out:
# ...
# Downloaded 191 investors
# scraping Nugroho Herucahyono
# scraping Achmad Zaky
# scraping Stephanie Yoe
# scraping Kusumo Martanto
# scraping Steve Sutanto
# scraping Dudung Rahmanto
# scraping Albert Albert
# scraping Sabda PS
# scraping Wisnu Subekti
# scraping Indra Adam Darmawan
# scraping Muhamad Iman Usman
# scraping Michaelangelo Moran
# scraping Kevin Aluwi
# scraping Dayu Dara Permata
# scraping Handy Chang
# scraping Hanindia Narendrata
# scraping Heru Susanto
# scraping Ahmad Priatama
# scraping Petra Barus
# scraping Arip Tirta
# scraping Joel Leong
# scraping Henry Chan
# scraping Bryan Chua
# scraping Leonardo Santoso
# scraping Pallav Kaushish
# scraping Christin Baumgarten
# scraping Ryoji Mori
# scraping Tomonori Tsuji
# scraping Daniel Witono
# scraping Anton Lucanus
# scraping Ganesh Kumar Bangah
# scraping Veronika Linardi
# scraping Claudia Widjaja
# scraping Jason Lamuda
# scraping Yenti Elizabeth
# scraping Ryan Gondokusumo
# scraping Wenes Kusnadi
# ...

# %%
# export each dataset type
# df_startupranking_founders, df_data_counter = convert_startupranking_to_df(founders_dict, nested_col='entity_founding_list', data_source = 'Startup Ranking (founder)', unique_cou_col='entity_company_founded_country',df_data_counter=df_data_counter)
df_startupranking_investors, df_data_counter = convert_startupranking_to_df(investors_dict, nested_col='entity_funding_list', data_source = 'Startup Ranking (investor)', unique_cou_col='entity_country',df_data_counter=df_data_counter)
df_startupranking_startups, df_data_counter = convert_startupranking_to_df(entity_dict, nested_col='entity_founders_list', data_source = 'Startup Ranking (startup)', unique_cou_col='entity_country',df_data_counter=df_data_counter)
# Out:
# Startup Ranking (investor) (225, 26)
# United States           65
# Japan                   22
# Indonesia               21
# Singapore               13
# China                   12
# Germany                  4
# South Korea              4
# United Kingdom           3
# Hong Kong SAR China      3
# United Arab Emirates     2
# India                    2
# Norway                   1
# Philippines              1
# Canada                   1
# Netherlands              1
# Thailand                 1
# Australia                1
# Switzerland              1
# Malaysia                 1
# Denmark                  1
# South Africa             1
# Name: entity_country, dtype: int64
# Startup Ranking (startup) (1656, 31)
# Indonesia    1580
# Vietnam        60
# Senegal        16
# Name: entity_country, dtype: int64

# %%
df_startupranking_founders.shape
# Out:
# (1512, 12)

# %% [markdown]
# ## Startup-ideas

# %%
df_startup_ideas_all = pd.DataFrame()
df_startup_ideas_founders_all = pd.DataFrame()

# %%
for country in country_list:
    # initialize
    page_num = 1
    root_url = 'http://www.startups-ideas.com/startups-around-world/startups/startups-list/startups-%s/page/%d/' % (str.lower(country), page_num)

    r = requests.get(root_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    # get max page
    max_cou_page = max([int(page.getText()) for page in soup.find("nav", {"class": "pagination"}).find_all('a') if page.getText().isdigit()])

    entity_dict = {}
    founder_dict = {}

    for page_num in range(1, max_cou_page+1):
        #pull page

        root_url = 'http://www.startups-ideas.com/startups-around-world/startups/startups-list/startups-%s/page/%d/' % (str.lower(country), page_num)
        r = requests.get(root_url)
        soup = bs4.BeautifulSoup(r.content, "lxml")

        # get all entities
        entity_list = soup.find("div", {"class":"list"}).find_all("article")

    #     print("pulling page %d with %d entities" % (page_num, len(entity_list)))
        if len(entity_list) > 0:
            for entity_entry in entity_list:
            # entity_entry = entity_list[0]
                entity_name = entity_entry.find("h2", {"class": "entry-title"}).getText()
                entity_dict[entity_name] = {}
                entity_dict[entity_name]['entity_type'] = 'startup'
                entity_dict[entity_name]['entity_logo_url'] = entity_entry.find('img')['src']
                entity_dict[entity_name]['entity_dir_url'] = entity_entry.find("h2", {"class": "entry-title"}).find('a')['href']
                address = entity_entry.find("p", {"class": "listing-address"}).getText()
                entity_dict[entity_name]['entity_address'] = address

                # remove address-related tags in the industry list
                industry_list = [cat.getText().strip().replace("Startups ","") for cat in entity_entry.find("p", {"class": "listing-cat"}).find_all('a')]
                entity_dict[entity_name]['entity_industry_list'] = list(set(industry_list) - set(address.replace(" ",'').split('-')))
                entity_dict[entity_name]['entity_contact_telno'] = entity_entry.find("p", {"class": "listing-phone"}).getText()

                # drop filler entity descriptions from results
                desc = entity_entry.find("p", {"class": "listing-description"}).getText()
                if ' You are looking for informations about' in desc:
                    entity_dict[entity_name]['entity_desc'] = ''
                else:
                    entity_dict[entity_name]['entity_desc'] = entity_entry.find("p", {"class": "listing-description"}).getText()

    # scrape each page
    for entity_name in list(entity_dict.keys()):
    #     print(entity_name)

        dir_url = entity_dict[entity_name]['entity_dir_url']
        r = requests.get(dir_url)
        soup = bs4.BeautifulSoup(r.content, "lxml")

        entity_dict[entity_name]['entity_url'] = soup.find('li', {"id":"listing-website"}).find('a')['href']

        # decode email
        try:
            encoded_email = soup.find("div", {"itemprop":"location"}).find('a',{'title':'Email'}).find('span')['data-cfemail']
            entity_dict[entity_name]['entity_contact_email'] = cfDecodeEmail(encoded_email)
        except:
            pass

        try:
            for social_media_entry in soup.find('div', {"id":"listing-follow"}).find_all('a'):
                entity_dict[entity_name]['entity_socmed_'+str.lower(social_media_entry['title'])] = social_media_entry['href']
        except:
            pass

        desc_section = soup.find('section', {"id":"overview"})

        stop_phrases = ['You are looking for',
                        'We don’t have information yet about',
                        'add your start-up to get backlinks and visibility on the Internet',
                       'to find open positions and jobs offers',
                       'You can follow',
                       'You can find news about']
        try:
            entity_dict[entity_name]['entity_desc_details'] = [desc.getText() for desc in desc_section.find_all('p') if not any(phrase in desc.getText() for phrase in stop_phrases)]
        except:
            pass

        try:
            entity_founder = desc_section.find('h2', string = '%s FOUNDERS & TEAM' % str.upper(entity_name)).nextSibling.find("span", {"style": "text-decoration: underline;"}).getText().split(' is the founder of ')[0]
            entity_dict[entity_name]['entity_founder'] = entity_founder
            entity_founder_position = desc_section.find('h2', string = '%s FOUNDERS & TEAM' % str.upper(entity_name)).nextSibling.find("span", {"style": "text-decoration: underline;"}).nextSibling.replace(" : ","")
            entity_dict[entity_name]['entity_founder_position'] = entity_founder_position
            founder_dict[entity_founder] = {
                'entity_company' : entity_name,
                'entity_position' : entity_founder_position
            }
        except:
            pass

        try:
            social_media_entry_list = desc_section.find('h2', string = '%s NEWS' % str.upper(entity_name)).nextSibling.find_all('a')
            if len(social_media_entry_list)>0:
                for social_media_entry in social_media_entry_list:
            #         print(str.lower(social_media_entry.getText()), social_media_entry['href'])
                    entity_dict[entity_name]['entity_socmed_'+str.lower(social_media_entry.getText())] = social_media_entry['href']
        except:
            pass
    
    # convert to dataframe and compile all startup data
    df_startup_ideas = pd.DataFrame.from_dict(entity_dict, orient='index')

    # drop test startup
    try:
        df_startup_ideas = df_startup_ideas.drop(index='00 TEST STARTUP')
    except:
        pass
    cols = list(df_startup_ideas.columns)
    cols = ['entity_name'] + cols

    df_startup_ideas = df_startup_ideas.reset_index()
    df_startup_ideas.columns = cols
    df_startup_ideas['entity_country'] = country
    df_startup_ideas_all = df_startup_ideas_all.append(df_startup_ideas)

    
    # convert to dataframe and compile all founder data
    df_startup_ideas_founders = pd.DataFrame.from_dict(founder_dict, orient='index')

    cols = list(df_startup_ideas_founders.columns)
    cols = ['entity_name'] + cols

    df_startup_ideas_founders = df_startup_ideas_founders.reset_index()
    df_startup_ideas_founders.columns = cols
    df_startup_ideas_founders['entity_country'] = country
    df_startup_ideas_founders_all = df_startup_ideas_founders_all.append(df_startup_ideas_founders)
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
df_startup_ideas_all['entity_country'].value_counts()
# Out:
# Indonesia    472
# Nigeria      328
# Vietnam      200
# Kenya        195
# Senegal       42
# Name: entity_country, dtype: int64

# %%
df_startup_ideas_founders_all['entity_country'].value_counts()
# Out:
# Indonesia    78
# Nigeria      57
# Kenya        39
# Vietnam      24
# Senegal       5
# Name: entity_country, dtype: int64

# %%
data_source = 'Startup Ideas (startups)'
df_startup_ideas_all.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_startup_ideas_all, df_data_counter, 'entity_country', exact_match=True)

# %%
data_source = 'Startup Ideas (founders)'
df_startup_ideas_founders_all.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_startup_ideas_founders_all, df_data_counter, 'entity_country', exact_match=True)

# %%
df_data_counter
# Out:
#                                     data_source number_of_extracted_cols  \
# 0  Compass List Directory (startups, investors)                        9
# 1             Compass List Directory (founders)                        8
# 2              Compass List profiles (startups)                       20
# 3                      Startup Ideas (startups)                       18
# 4                      Startup Ideas (founders)                        4
# 5                      Startup Ideas (startups)                       18
# 6                      Startup Ideas (founders)                        4
#
#   Senegal Indonesia Vietnam Kenya Nigeria
# 0       0       183       0     0       0
# 1       0       278       0     0       0
# 2       0       120       0     0       0
# 3       0       472       0     0       0
# 4       0        78       0     0       0
# 5      42       472     200   195     328
# 6       5        78      24    39      57

# %% [markdown]
# ## Private Banking

# %%
base_url = 'https://www.privatebanking.com'
# create initial dictionaries
df_private_banking_all = pd.DataFrame()

# %%
for country in country_list:
    entity_dict = {}
    if country in ['Indonesia','Vietnam']:
        region = 'asia'
    elif country in ['Nigeria', 'Senegal', 'Kenya']:
        region = 'africa'
    # identify all entity types
    dir_cou_url = '/directory/%s-%s'% (region, str.lower(country))
    
    r = requests.get(base_url + dir_cou_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    category_dict = {}
    category_list = soup.find('td', {'class': 'main-text-caption-darkblue'}, string='Categories %s' % country).findNext('td').find_all('a')
    
    for cat_entry in category_list:
        if not cat_entry.find('img'):
            category_dict[str.lower(cat_entry['title'])] = cat_entry['href']
    
    print("Downloading %d categories from %s" % (len(list(category_dict.keys())), country))
    
    for entity_type in list(category_dict.keys()):
    # entity_type = list(category_dict.keys())[2]
        print("Downloading entity type %s" % (entity_type))

        page_num = 1
        # dir_url = '/directory/asia-%s/%s?random=1&page=%d' % (str.lower(country), entity_type,page_num)
        dir_url = category_dict[entity_type] + "&page=%d" % page_num

        # get max page
        r = requests.get(base_url + dir_url)
        soup = bs4.BeautifulSoup(r.content, "lxml")

        max_page_val_entity = 1
        if soup.find_all('a', {'class': 'page-counter-0'}):
            max_page_val_entity = max([int(page.getText()) for page in soup.find_all('a', {'class': 'page-counter-0'}) if page.getText().isdigit()])

        # go through directory page
        dir_list = soup.find_all('a', {"class":"list-banks-1", "style": "color: #325783;"})
        for dir_entry in dir_list:
            entity_name = dir_entry.getText()
            
            if entity_name not in list(entity_dict.keys()):
                entity_dict[entity_name] = {}
                entity_dict[entity_name]['entity_dir_url'] =  base_url + dir_entry['href']
                entity_dict[entity_name]['entity_type_list'] = []
                entity_dict[entity_name]['entity_type_list'].append(entity_type)
                entity_dict[entity_name]['entity_country'] = country
                
            else:
                entity_dict[entity_name]['entity_type_list'].append(entity_type)
        print("Downloaded page %d with %d entities" % (page_num, len(dir_list)))
        
        if max_page_val_entity > 1:
            for page_num in range(2, max_page_val_entity+1):
                dir_url = category_dict[entity_type] + "&page=%d" % page_num

                # get max page
                r = requests.get(base_url + dir_url)
                soup = bs4.BeautifulSoup(r.content, "lxml")
                # go through directory page
                dir_list = soup.find_all('a', {"class":"list-banks-1", "style": "color: #325783;"})
                for dir_entry in dir_list:
                    if entity_name not in list(entity_dict.keys()):
                        entity_dict[entity_name] = {}
                        entity_dict[entity_name]['entity_dir_url'] =  base_url + dir_entry['href']
                        entity_dict[entity_name]['entity_type_list'] = []
                        entity_dict[entity_name]['entity_type_list'].append(entity_type)
                        entity_dict[entity_name]['entity_country'] = country

                    else:
                        entity_dict[entity_name]['entity_type_list'].append(entity_type)
                print("Downloaded page %d with %d entities" % (page_num, len(dir_list)))
        
    # go through entity pages
    for entity_name in list(entity_dict.keys()):
    #     entity_name = list(entity_dict.keys())[0]

        entity_dir_url = entity_dict[entity_name]['entity_dir_url']

        r = requests.get(entity_dir_url)
        soup = bs4.BeautifulSoup(r.content, "lxml")

        attribute_list = soup.find_all('td', {'class':'main-text-bold'})
        for attribute_entry in attribute_list:
            if attribute_entry.getText().strip() != '':
                attribute_type = attribute_entry.getText().strip().replace(':','')
                attribute_val = attribute_entry.findNext('td').getText().strip()

                entity_dict[entity_name]['entity_' + str.lower(attribute_type)] = attribute_val
                
        entity_type_list = []
        cat_list = soup.find('td', {'class': 'main-text-caption-darkblue'}, string='Business Categories').findNext('table').find_all('a')

        for cat_entry in cat_list:
            if not cat_entry.find('img'):
                entity_type_list.append(str.lower(cat_entry['title']))
                
        entity_dict[entity_name]['entity_type_list_page'] = entity_type_list

    # convert to dataframe and compile all entity data
    df_private_banking = pd.DataFrame.from_dict(entity_dict, orient='index')

    cols = list(df_private_banking.columns)
    cols = ['entity_name'] + cols

    df_private_banking = df_private_banking.reset_index()
    df_private_banking.columns = cols
#     print(df_private_banking['entity_type'].value_counts())
    
    df_private_banking_all = df_private_banking_all.append(df_private_banking)

# %%
data_source = 'Private Banking'
df_private_banking_all.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_private_banking_all, df_data_counter, 'entity_country', exact_match=True)

# %%
entity_type = 'banks'
df_private_banking_all[(df_private_banking_all['entity_type_list_page'].apply(lambda x: entity_type in x))]['entity_country'].value_counts()

# %%
entity_type = 'venture capital'
df_private_banking_all[(df_private_banking_all['entity_type_list_page'].apply(lambda x: entity_type in x))]['entity_country'].value_counts()

# %%
entity_type = 'angel investors'
df_private_banking_all[(df_private_banking_all['entity_type_list_page'].apply(lambda x: entity_type in x))]['entity_country'].value_counts()

# %%
entity_type_set = set()
for a in df_private_banking_all['entity_type_list_page'].values.tolist():
    entity_type_set = entity_type_set | set(a)

# %%
df_private_banking_all['entity_country'].value_counts()

# %% [markdown]
# ## Scholaro

# %%
data_source = "Scholaro (university)"
entity_list = []

# %%
country_list
# Out:
# ['Indonesia', 'Senegal', 'Vietnam', 'Kenya', 'Nigeria']

# %%
for country in ['Senegal', 'Vietnam', 'Kenya', 'Nigeria']:
    root_url = 'https://www.scholaro.com'
    dir_url = '/ed/Countries/%s/Universities' % country

    print(root_url+dir_url)
    r = requests.get(root_url + dir_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")
    dir_cols = [th.getText() for th in soup.find('div', {'class': 'k-grid-header'}).find_all('th')]
    dir_list = soup.find('tbody').find_all('tr')
    
    # get full directory per country page
    for dir_entry in dir_list:
        entry_list = [entry.getText() for entry in dir_entry.find_all('td')]
        row_dict = {}
        row_dict['entity_dir_url'] = root_url + dir_entry.find('a')['href']
        row_dict['entity_country'] = country
        row_dict['entity_type'] = 'university'
        for header, val in zip(dir_cols, entry_list):
            row_dict['entity_'+str.lower(header)] = val
        entity_list.append(row_dict)
    print("Downloading %d universities for %s" % (len(dir_list), country))
# Out:
# https://www.scholaro.com/ed/Countries/Senegal/Universities
# ...
# https://www.scholaro.com/ed/Countries/Vietnam/Universities
# ...
# https://www.scholaro.com/ed/Countries/Kenya/Universities
# ...
# https://www.scholaro.com/ed/Countries/Nigeria/Universities
# ...

# %%
# go to university page
for entity_vals in entity_list:
    entity_dir_url = entity_vals['entity_dir_url']
    r = requests.get(entity_dir_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    try:
        table_list = soup.find_all('table', {"class": "hiddenTable"})

        if len(table_list) > 0:
            for table in table_list:
                for ent in table.find_all('tr'):
                    header = ent.find('td').getText().replace(':', '').strip()
                    val = ent.find('td').findNext('td').getText().strip()
                    entity_vals['entity_'+str.lower(header.replace(' ','_'))] = val

        url_list = soup.find('h2', string='Links').parent.find_all('a')

        if len(url_list) > 0:
            for url in url_list:
                entity_vals['entity_url_'+str.lower(url.getText().strip().replace(' ','_'))] = url['href']

        address_list = soup.find('div', {'id': 'refaddress'}).find_all('span')

        if len(address_list) > 0:
            for address in address_list:
                if address.has_attr('itemprop'):
                    header = 'entity_address_'+str.lower(address['itemprop'])

                    if header not in entity_vals.keys():
                        entity_vals[header] = address.getText().strip()
                    else:
                        val = entity_vals[header]
                        val += ', ' + address.getText().strip()
                        entity_vals[header] = val

        phone_num = soup.find('span', {'id': 'reftel'})
        if phone_num:
            entity_vals['entity_contact_tel'] = phone_num.getText()
    except:
        pass

# %%
df_scholaro_id = df_scholaro.copy()

# %%
df_scholaro = pd.DataFrame(entity_list)

# %%
df_scholaro_all = df_scholaro.append(df_scholaro_id)

# %%
df_scholaro_all.shape
# Out:
# (738, 27)

# %%
df_scholaro_all['entity_country'].value_counts()
# Out:
# Indonesia    312
# Kenya        195
# Vietnam      117
# Nigeria       96
# Senegal       18
# Name: entity_country, dtype: int64

# %%
data_source = "Scholaro (university)"
df_scholaro_all.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_scholaro_all, df_data_counter, 'entity_country', exact_match=True)

# %% [markdown]
# # Indonesia-specific Associations

# %% [markdown]
# ## ASPILUKI

# %%
root_url = 'http://www.aspiluki.or.id/index.php?option=com_content&view=article&id=60&Itemid=65'
r = requests.get(root_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# %%
entity_list = [comp.getText().strip() for comp in soup.find('div', {'class': 'article-content'}).find_all('p')]
df_aspiluki = pd.DataFrame(entity_list, columns = ['entity_name'])
df_aspiluki['entity_type'] = 'company'
df_aspiluki['entity_country'] = 'Indonesia'
df_aspiluki['entity_industry'] = 'Telematics Software'

# %%
data_source = "ASPILUKI (company)"
df_aspiluki.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_aspiluki, df_data_counter, 'entity_country', exact_match=True)

# %%
df_aspiluki.shape
# Out:
# (100, 4)

# %% [markdown]
# ## APMI

# %%
root_url = 'http://apmi.or.id/page/daftar-keanggotaan.html'
r = requests.get(root_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# %%
entity_list = []

headers = [tr.find('p').getText() for tr in soup.find('table').find_all('tr')[0] if tr != '\n']
entry_list = soup.find('table').find_all('tr')[1:]

for entry in entry_list:
# entry = entry_list[0]
    entry_vals = [p.getText() for p in entry.find_all('p')]
    row_dict= {}
    for header, val in zip(headers, entry_vals):
        row_dict[header]= val
    entity_list.append(row_dict)

# %%
df_apmi = pd.DataFrame(entity_list)
df_apmi.columns = ['entity_industry_subtype', 'entity_name', 'index', 'entity_type_association']
df_apmi = df_apmi.drop(['index'], axis=1)

# %%
df_apmi['entity_type'] = 'company'
df_apmi['entity_country'] = 'Indonesia'
df_apmi['entity_industry'] = 'Multimedia'

# %%
df_apmi.shape
# Out:
# (27, 6)

# %%
data_source = "APMI (company)"
df_apmi.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_apmi, df_data_counter, 'entity_country', exact_match=True)

# %% [markdown]
# ## ABDI

# %%
root_url = 'http://www.abdi.id/manfaat-bergabung/'

# %%
r = requests.get(root_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# %%
entity_list = [comp.getText() for comp in soup.find('div', {'class': 'wpb_content_element'}).find_all('strong')[1:13]]

# %%
df_abdi = pd.DataFrame(entity_list, columns = ['entity_name'])
df_abdi['entity_type'] = 'company'
df_abdi['entity_country'] = 'Indonesia'
df_abdi['entity_industry'] = 'Big data & AI'

# %%
data_source = "ABDI (company)"
df_abdi.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_abdi, df_data_counter, 'entity_country', exact_match=True)

# %% [markdown]
# ## APKOMINDO

# %%
def extract_apkomindo_directory(page_num, entity_list):
    root_url = 'http://www.apkomindojatim.com/'
    dir_url = 'member.php?page=%d&amp;cID=&amp;city=&amp;sort=&amp;action=&amp;act=' % page_num
    
    r = requests.get(root_url + dir_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")
    
    table_section = soup.find("div", {"class": "title2"}, string='Direktori').parent.find('td', string='Nama Perusahaan').findPrevious('table')

    # extract directory
    dir_list_dark = table_section.find_all('tr', {'style':'background-color:#F8F9F3; '})
    dir_list_white = table_section.find_all('tr', {'style':'background-color:#FFFFFF; '})
    headers = [header.getText() for header in dir_list_dark[0].find_all('td')]

    entry_list = dir_list_dark[1:]
    for entry_row in entry_list:
        entry_vals = [entry.getText() for entry in entry_row.find_all('td')]
        row_dict = {}
        row_dict['entity_url_dir'] = root_url + entry_row.find('a')['href']
        for header, val in zip(headers, entry_vals):
            row_dict[header]= val
        entity_list.append(row_dict)

    entry_list = dir_list_white
    for entry_row in entry_list:
        entry_vals = [entry.getText() for entry in entry_row.find_all('td')]
        row_dict = {}
        row_dict['entity_url_dir'] = root_url + entry_row.find('a')['href']
        for header, val in zip(headers, entry_vals):
            row_dict[header]= val
        entity_list.append(row_dict)
        
    return(entity_list)

# %%
root_url = 'http://www.apkomindojatim.com/'
dir_url = 'member.php?page=%d&amp;cID=&amp;city=&amp;sort=&amp;action=&amp;act=' % page_num

# initialize
page_num = 1
entity_list = []

# %%
r = requests.get(root_url + dir_url)
soup = bs4.BeautifulSoup(r.content, "lxml")
table_section = soup.find("div", {"class": "title2"}, string='Direktori').parent.find('td', string='Nama Perusahaan').findPrevious('table')
max_dir_page = max([int(a.getText()) for a in table_section.findNext('div').find_all('a') if a.getText().isdigit()])

if max_dir_page > 1:
    for page_num in range(1,max_dir_page+1):
        entity_list = extract_apkomindo_directory(page_num, entity_list)

# %%
for entity_vals in entity_list:
# entity_vals = entity_list[0]
    entity_url_dir = entity_vals['entity_url_dir']

    r = requests.get(entity_url_dir)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    entry_list = soup.find('td', string='Nama Perusahaan').findPrevious('table').find_all('tr')
    for entry in entry_list:
        if entry.getText().strip() != '':
            header = str.lower(entry.find('td').getText()).replace(' ','_')
            vals = entry.find('td', {'style':'background-color:#E8E8E8; padding:4px; color:#000000; '}).getText()
            entity_vals['entity_'+header] = vals

# %%
df_apkomindo = pd.DataFrame(entity_list).drop(['Alamat', 'Nama Perusahaan', 'Telepon'], axis=1)
df_apkomindo.columns = ['entity_address', 'entity_contact_person', 'entity_contact_email', 'entity_contact_fax',
       'entity_industry_subtype', 'entity_name', 'entity_contact_telephone',
       'entity_url_dir']

# %%
df_apkomindo['entity_type'] = 'company'
df_apkomindo['entity_country'] = 'Indonesia'
df_apkomindo['entity_industry'] = 'Computers'

# %%
df_apkomindo.shape
# Out:
# (58, 11)

# %%
data_source = "APKOMINDO (company)"
df_apkomindo.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_apkomindo, df_data_counter, 'entity_country', exact_match=True)

# %% [markdown]
# ## FinTech ID

# %%
root_url = 'https://fintech.id'
dir_url = '/membership#membership'

# %%
r = requests.get(root_url + dir_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# %%
entity_dict = {}

# %%
entity_type_dict = {
    'startup': 'anggota',
    'financial institutions': 'lembaga',
    'association partner': 'mitra'
}

# %%
for entity_type, entity_keyword in entity_type_dict.items():
    entry_list = soup.find('div', {'id': entity_keyword}).find_all('div', {'class': 'member-col'})
    for entry in entry_list:
        entity_name = entry.find('span').getText().strip()
        entity_dict[entity_name] = {}
        entity_dict[entity_name]['entity_url_website'] = entry.find('a')['href']
        entity_dict[entity_name]['entity_photo_logo'] = root_url + entry.find('img')['src']
        entity_dict[entity_name]['entity_type'] = entity_type

# %%
df_fintechid = pd.DataFrame.from_dict(entity_dict, orient='index').reset_index()
df_fintechid.columns = ['entity_name', 'entity_url_website', 'entity_photo_logo', 'entity_type']
df_fintechid['entity_country'] = 'Indonesia'
df_fintechid['entity_industry'] = 'Fintech'

# %%
df_fintechid.shape
# Out:
# (176, 6)

# %%
df_fintechid['entity_type'].value_counts()
# Out:
# startup                   143
# financial institutions     24
# association partner         9
# Name: entity_type, dtype: int64

# %%
data_source = "Fintech ID (startup, financial institution, partner)"
df_fintechid.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_fintechid, df_data_counter, 'entity_country', exact_match=True)

# %% [markdown]
# ## IDEA

# %%
root_url = 'https://www.idea.or.id/direktori-member'
r = requests.get(root_url)
soup = bs4.BeautifulSoup(r.content, "lxml")

# %%
entity_list = []

# %%
entity_sections = soup.find('div', {"class": 'boxdircontent'}).find_all('div', {"class": "col-md-12 col-sm-12 col-xs-12 nopadding wow fadeIn"})
for entity_section in entity_sections:
    entity_type = str.lower(entity_section.find('div', {'style': 'border-bottom:1px solid #6e6e6e; background:#6e6e6e; color:#ffffff; padding:15px; font-weight:bold; font-size:18px;'}).getText().strip())

    for entity in entity_section.find_all('div', {'class': 'col-md-3 col-sm-4 col-xs-12 mt15 mb15'}):
        row_dict = {}
        row_dict['entity_url_website'] = entity.find('a')['href']
        row_dict['entity_photo_logo'] = entity.find('img')['src']
        row_dict['entity_type'] = entity_type
        entity_list.append(row_dict)

# %%
df_idea = pd.DataFrame(entity_list)
df_idea['entity_country'] = 'Indonesia'
df_idea['entity_industry'] = 'E-commerce'

# %%
df_idea.shape
# Out:
# (321, 5)

# %%
df_idea['entity_type'].value_counts()
# Out:
# online retail      147
# marketplace         54
# infrastructure      30
# payment gateway     21
# logistik            19
# classified ads      19
# travel              17
# bank                 7
# dailydeals           6
# directory            1
# Name: entity_type, dtype: int64

# %%
data_source = "IDEA (company)"
df_idea.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_idea, df_data_counter, 'entity_country', exact_match=True)

# %% [markdown]
# ## APJII

# %%
def extract_apjii_data(root_url, entity_dict):
    r = requests.get(root_url)
    soup = bs4.BeautifulSoup(r.content, "lxml")

    entity_list = soup.find('ul', {'class':'pagination img-anggotakami'}).find_all('li')
    for entity in entity_list:
        entity_name = entity.find('a')['title']
        entity_dict[entity_name] = {}
        entity_dict[entity_name]['entity_photo_logo'] = entity.find('img')['src']
        entity_content = entity.find('a')['data-content']
        soup_content = bs4.BeautifulSoup(html.unescape(entity_content).strip(), "lxml")
        entry_list = soup_content.find('table').find_all('tr')
        for entry in entry_list:
            header = entry.find_all('td')[0].getText().strip()
            val = entry.find_all('td')[-1].getText().strip()
            entity_dict[entity_name][header] = val
    
    return(entity_dict, soup)

# %%
entity_dict = {}

# %%
root_url = 'https://www.apjii.or.id/anggota/index'
entity_dict, soup = extract_apjii_data(root_url, entity_dict)

# %%
# check if there is a next button
while soup.find_all('ul', {'class': 'pagination'})[-1].find('a', {'rel': 'next'}):
    root_url = soup.find_all('ul', {'class': 'pagination'})[-1].find('a', {'rel': 'next'})['href']
    print(root_url)
    entity_dict, soup = extract_apjii_data(root_url, entity_dict)
# Out:
# https://www.apjii.or.id/anggota/index/35
# https://www.apjii.or.id/anggota/index/70
# https://www.apjii.or.id/anggota/index/105
# https://www.apjii.or.id/anggota/index/140
# https://www.apjii.or.id/anggota/index/175
# https://www.apjii.or.id/anggota/index/210
# https://www.apjii.or.id/anggota/index/245
# https://www.apjii.or.id/anggota/index/280
# https://www.apjii.or.id/anggota/index/315
# https://www.apjii.or.id/anggota/index/350
# https://www.apjii.or.id/anggota/index/385
# https://www.apjii.or.id/anggota/index/420
# https://www.apjii.or.id/anggota/index/455
# https://www.apjii.or.id/anggota/index/490

# %%
df_apjii = pd.DataFrame.from_dict(entity_dict, orient='index')
df_apjii = df_apjii.reset_index()
df_apjii.columns = ['entity_name', 'entity_photo_logo', 'entity_association_membership_type', 'entity_services_licensing_type',
       'entity_url_website', 'entity_address', 'entity_address_subdistrict', 'entity_address_district', 'entity_address_city', 'entity_address_province',
       'entity_address_district_postal_code', 'entity_contact_phone', 'entity_contact_fax', 'entity_id_asn']

# %%
df_apjii['entity_country'] = 'Indonesia'
df_apjii['entity_industry'] = 'Internet Service Provider'
df_apjii['entity_type'] = 'company'

# %%
df_apjii.shape
# Out:
# (517, 17)

# %%
df_apjii['entity_type'].value_counts()
# Out:
# company    517
# Name: entity_type, dtype: int64

# %%
data_source = "APJII (company)"
df_apjii.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_apjii, df_data_counter, 'entity_country', exact_match=True)

# %% [markdown]
# # Indonesia-specific articles

# %% [markdown]
# ## inc42

# %%
# scraper = cfscrape.create_scraper() 

# root_url = 'https://inc42.com/indonesia/accelerators-incubators-indonesia/'
# r = scraper.get(root_url)
# soup = bs4.BeautifulSoup(r.content, "lxml")

# entity_dict = {}

# entity_list = [entity for entity in soup.find_all('a', {'class': 'external', 'rel':'noopener noreferrer nofollow'}) if entity.getText() != '']
# entity_name_list = [entity.getText() for entity in soup.find_all('a', {'class': 'external', 'rel':'noopener noreferrer nofollow'}) if entity.getText() != '']

# ix = 0
# entity_name_raw = entity_name_list[ix]
# entity = entity_list[ix]
# entity_name = entity_name_raw.strip()
# entity_dict[entity_name] = {}

# entity_dict[entity_name]['entity_url_website'] = entity['href']
# if entity.findPrevious('a').find('img'):
#     entity_dict[entity_name]['entity_photo_logo'] = entity.findPrevious('a').find('img')['data-cfsrc']
    
# entity_dict[entity_name]['entity_desc'] = entity.findNext('p').getText()

# %%
glob.glob('data/*.csv')
# Out:
# ['data\\2018-09-12 - inc42 accelerators.csv',
#  'data\\2018-09-12 - inc42 incubators.csv',
#  'data\\wbg_country_metadata.csv']

# %%
inc42_acc = pd.read_csv('data\\2018-09-12 - inc42 accelerators.csv', encoding='latin-1')
df_inc42_acc = inc42_acc.set_index(['grp', 'header']).unstack(level=-1).reset_index(drop=True)
df_inc42_acc.columns = ['entity_address', 'entity_desc', 'entity_funding_list', 'entity_industry_list', 'entity_name', 'entity_services_duration', 'entity_services_num_batches_graduated', 'entity_services_num_startups', 'entity_services_structure', 'entity_url_website', 'entity_year_start']
df_inc42_acc['entity_type'] = 'accelerator'

# %%
inc42_inc = pd.read_csv('data\\2018-09-12 - inc42 incubators.csv', encoding='latin-1')

# %%
df_inc42_inc = inc42_inc.set_index(['grp', 'header']).unstack(level=-1).reset_index(drop=True)
df_inc42_inc.columns = ['entity_address', 'entity_desc', 'entity_funding_list', 'entity_industry_list', 'entity_name', 'entity_services_duration', 'entity_services_num_batches_graduated', 'entity_services_num_startups', 'entity_services_structure', 'entity_url_website', 'entity_year_start']
df_inc42_inc['entity_type'] = 'incubator'

# %%
df_inc42 = pd.concat([df_inc42_inc, df_inc42_acc]).reset_index(drop=True)

# %%
df_inc42['entity_country'] = 'Indonesia'

# %%
df_inc42.shape
# Out:
# (20, 13)

# %%
df_inc42['entity_type'].value_counts()
# Out:
# incubator      12
# accelerator     8
# Name: entity_type, dtype: int64

# %%
data_source = "Inc42 (accelerator, incubator)"
df_inc42.to_csv(os.path.join(output_folder, raw_outputs_folder,"%s - %s.csv" % (date_today, data_source)), index=False)

# update data counter
df_data_counter = update_data_counter(data_source, country_list, df_inc42, df_data_counter, 'entity_country', exact_match=True)
